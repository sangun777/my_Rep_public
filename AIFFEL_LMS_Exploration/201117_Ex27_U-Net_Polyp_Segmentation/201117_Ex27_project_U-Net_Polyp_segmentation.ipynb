# %% [markdown]
# ## 27-6. 프로젝트: U-Net 성능 개선해 보기

# %% [markdown]
# ### STEP 1 : 데이터셋 구성
#
#  * 오늘 실습에서 활용하였던 Giana 데이터셋을 그대로 활용하여,
#  * augmentation을 위한 파이프라인 구성 및
#  * tf.data.Dataset을 이용한 배치처리를 통해 학습/테스트 데이터셋을 구성합니다.

# %%
# 필요 라이브러리 로딩
from __future__ import absolute_import, division
from __future__ import print_function, unicode_literals

import os
import time
import shutil
import functools

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib as mpl
mpl.rcParams['axes.grid'] = False
mpl.rcParams['figure.figsize'] = (12,12)

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import matplotlib.image as mpimg
import pandas as pd
from PIL import Image
from IPython.display import clear_output

import tensorflow as tf
import tensorflow_addons as tfa
print(tf.__version__)

from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras import models
# Out:
# 2.3.1

# %% [markdown]
# * 데이터 다운 및 압축 풀기

# %%
DATASET_PATH=os.path.join(os.getenv('HOME'),'aiffel/medical')

# %%
if not os.path.isdir(DATASET_PATH):
    os.makedirs(DATASET_PATH)

# %%
import urllib.request

# %%
u = urllib.request.urlopen(url='https://aiffelstaticprd.blob.core.windows.net/media/documents/sd_train.zip')
data = u.read()
u.close()

with open('sd_train.zip', "wb") as f :
    f.write(data)
    print('Data has been downloaded')

shutil.move(os.path.join('sd_train.zip'), os.path.join(DATASET_PATH))
file_path = os.path.join(DATASET_PATH, 'sd_train.zip')

import zipfile
zip_ref = zipfile.ZipFile(file_path, 'r')
zip_ref.extractall(DATASET_PATH)
zip_ref.close()
print('Data has been extracted.')

# %% [markdown]
# ### Train / Test Dataset 분리

# %%
img_dir = os.path.join(DATASET_PATH, "train")
label_dir = os.path.join(DATASET_PATH, "train_labels")

# %%
x_train_filenames = [os.path.join(img_dir, filename) for filename in os.listdir(img_dir)]
x_train_filenames.sort()
y_train_filenames = [os.path.join(label_dir, filename) for filename in os.listdir(label_dir)]
y_train_filenames.sort()

# %%
x_train_filenames, x_test_filenames, y_train_filenames, y_test_filenames = \
                    train_test_split(x_train_filenames, y_train_filenames, test_size=0.2)

# %%
num_train_examples = len(x_train_filenames)
num_test_examples = len(x_test_filenames)

print("Number of training examples: {}".format(num_train_examples))
print("Number of test examples: {}".format(num_test_examples))
# Out:
# Number of training examples: 480
# Number of test examples: 120

# %% [markdown]
# ### Visualization
#
#  * 데이터 셋에서 이미지 샘플을 5개 정도 살펴보기

# %%
display_num = 5

r_choices = np.random.choice(num_train_examples, display_num)

plt.figure(figsize=(10, 15))
for i in range(0, display_num * 2, 2):
    img_num = r_choices[i // 2]
    x_pathname = x_train_filenames[img_num]
    y_pathname = y_train_filenames[img_num]

    plt.subplot(display_num, 2, i + 1)
    plt.imshow(Image.open(x_pathname))
    plt.title("Original Image")

    example_labels = Image.open(y_pathname)
    label_vals = np.unique(example_labels)

    plt.subplot(display_num, 2, i + 2)
    plt.imshow(example_labels)
    plt.title("Masked Image")
    
plt.suptitle("Examples of Images and their Masks")
plt.show()

# %% [markdown]
# ### hyper-parameters 셋팅

# %%
# Set hyperparameters

image_size = 256
img_shape = (image_size, image_size, 3)
batch_size = 8
max_epochs = 50

# %% [markdown]
# ### tf.data를 활용한 입력 파이프라인 설계

# %% [markdown]
# ### Processing each pathname
#
#    * byte 형태로 데이터를 로드하고, bmp로 디코딩
#    * 디코딩이 완료된 image를 scale과 size를 조절

# %%
def _process_pathnames(fname, label_path):
    # We map this function onto each pathname pair
    img_str = tf.io.read_file(fname)
    img = tf.image.decode_bmp(img_str, channels=3) # RGB

    label_img_str = tf.io.read_file(label_path)
    label_img = tf.image.decode_bmp(label_img_str, channels=1) # BMP 0,1

    resize = [image_size, image_size]
    img = tf.image.resize(img, resize)
    label_img = tf.image.resize(label_img, resize)

    scale = 1 / 255.
    img = tf.cast(img, dtype=tf.float32) * scale
    label_img = tf.cast(label_img, dtype=tf.float32) * scale

    return img, label_img

# %% [markdown]
# ### Data augmentation - Shifting the image
#
#  * 아래는 로드한 이미지를 기반으로 이미지의 위치를 적절히 이동(shift)시키는 함수
#  * 입력이미지와 라벨의 쌍을 동일하게 shift 시켜야함

# %%
def shift_img(output_img, label_img, width_shift_range, height_shift_range):
    """This fn will perform the horizontal or vertical shift"""
    if width_shift_range or height_shift_range:
        if width_shift_range:
                width_shift_range = tf.random.uniform([],
                                                  -width_shift_range * img_shape[1],
                                                  width_shift_range * img_shape[1])
        if height_shift_range:
                height_shift_range = tf.random.uniform([],
                                                   -height_shift_range * img_shape[0],
                                                   height_shift_range * img_shape[0])
        output_img = tfa.image.translate(output_img,
                                         [width_shift_range, height_shift_range])
        label_img = tfa.image.translate(label_img,
                                        [width_shift_range, height_shift_range])
    return output_img, label_img

# %% [markdown]
# ### Data augmentation - Flipping the image randomly
#
#  * 아래는 로드한 이미지를 기반으로 이미지를 flip
#  * 50%의 확률로 좌우반전만 구현하였고, 상하반전은 적용하지 않음

# %%
def flip_img(horizontal_flip, tr_img, label_img):
    if horizontal_flip:
        flip_prob = tf.random.uniform([], 0.0, 1.0)
        tr_img, label_img = tf.cond(tf.less(flip_prob, 0.5),
                                lambda: (tf.image.flip_left_right(tr_img), tf.image.flip_left_right(label_img)),
                                lambda: (tr_img, label_img))
    return tr_img, label_img

# %% [markdown]
# ### Data augmentation Assembling
#
# * 위에서 구현한 Augmentation용 함수를 이용해 Data augmentation에 사용하는 _augment() 함수를 구성
#  * 위에서 적용한 것들 이외에도 resize, hue_delta가 적용

# %%
def _augment(img,
             label_img,
             resize=None,  # Resize the image to some size e.g. [256, 256]
             scale=1,  # Scale image e.g. 1 / 255.
             hue_delta=0.,  # Adjust the hue of an RGB image by random factor
             horizontal_flip=True,  # Random left right flip,
             width_shift_range=0.05,  # Randomly translate the image horizontally
             height_shift_range=0.05):  # Randomly translate the image vertically 
    if resize is not None:
        # Resize both images
        label_img = tf.image.resize(label_img, resize)
        img = tf.image.resize(img, resize)
  
    if hue_delta:
        img = tf.image.random_hue(img, hue_delta)
  
    img, label_img = flip_img(horizontal_flip, img, label_img)
    img, label_img = shift_img(img, label_img, width_shift_range, height_shift_range)
    label_img = tf.cast(label_img, dtype=tf.float32) * scale
    img = tf.cast(img, dtype=tf.float32) * scale
    return img, label_img

# %% [markdown]
# ### Set up train and test datasets
#
#  * tf.data.Dataset을 이용하여 데이터셋 배치구성, 셔플링 등을 구현
#  * 위에서 만든 augmentation도 함께 적용
#  * Train dataset에서만 Data augmentation을 진행하게 설정하는 것에 주의

# %%
def get_baseline_dataset(filenames,
                         labels,
                         preproc_fn=functools.partial(_augment),
                         threads=4,
                         batch_size=batch_size,
                         is_train=True):
    num_x = len(filenames)
    # Create a dataset from the filenames and labels
    dataset = tf.data.Dataset.from_tensor_slices((filenames, labels))
    # Map our preprocessing function to every element in our dataset, taking
    # advantage of multithreading
    dataset = dataset.map(_process_pathnames, num_parallel_calls=threads)

    if is_train:# 학습을 진행할시에만 위에 augment를 진행합니다.
        #if preproc_fn.keywords is not None and 'resize' not in preproc_fn.keywords:
        #  assert batch_size == 1, "Batching images must be of the same size"
        dataset = dataset.map(preproc_fn, num_parallel_calls=threads)
        dataset = dataset.shuffle(num_x * 10)

    dataset = dataset.batch(batch_size)
    return dataset

# %%
train_dataset = get_baseline_dataset(x_train_filenames, # 학습 데이터
                                     y_train_filenames) # 정답 데이터
train_dataset = train_dataset.repeat()
test_dataset = get_baseline_dataset(x_test_filenames,
                                    y_test_filenames,
                                    is_train=False)
train_dataset
# Out:
# <RepeatDataset shapes: ((None, 256, 256, 3), (None, 256, 256, 1)), types: (tf.float32, tf.float32)>

# %% [markdown]
# ### Plot some train data
#
#  * data augmentation 효과 적용 확인

# %%
for images, labels in train_dataset.take(1):
    # Running next element in our graph will produce a batch of images
    plt.figure(figsize=(10, 10))
    img = images[0]

    plt.subplot(1, 2, 1)
    plt.imshow(img)

    plt.subplot(1, 2, 2)
    plt.imshow(labels[0, :, :, 0])
    plt.show()

# %% [markdown]
# ### STEP 2 : pretrained model을 활용한 U-Net 모델 구성
#
# Encoder를 pretrained 모델로 변경하는 작업을 어떻게 진행하면 좋을까요? 아래 예시는 VGG16을 활용하기 위한 것입니다. 마음에 드는 다른 모델을 활용하기 위해 다양하게 시도해 보는 것을 권장합니다.
#
# 우선 VGG16 모델의 레이어 구성을 확인해 봅시다. U-Net이란 Encoder와 Decoder 사이의 대응되는 레이어간의 skip connection이 특징인 모델입니다. 여기서 Encoder를 pretrained model로 바꿔주려면 Encoder로 활용할 모델의 레이어 구성을 눈여겨 봐야겠죠?

# %% [markdown]
# ### STEP 3 : 학습과 테스트, 시각화
#
#  * 모델을 변경하여 실습과정과 동일하게 학습과 테스트, 시각화를 진행합니다.

# %% [markdown]
# ### STEP 4 : 모델 성능 비교분석
#
# * Encoder-Decoder 모델, U-Net 모델, Pretrained U-Net 모델 이상 3가지에 대해
# * 학습 진행과정, 정량/정성적 테스트 결과를 포함한 비교분석을 진행하여 봅니다.

# %% [markdown]
# ## Encoder-Decoder 모델

# %%
# inputs: [batch_size, 256, 256, 3]
encoder = tf.keras.Sequential(name='encoder')

# conv-batchnorm-activation-maxpool
encoder.add(layers.Conv2D(64, (3, 3), padding='same'))
encoder.add(layers.BatchNormalization())
encoder.add(layers.Activation('relu'))
encoder.add(layers.Conv2D(64, (3, 3), strides=2, padding='same'))
encoder.add(layers.BatchNormalization())
encoder.add(layers.Activation('relu')) # conv1: [batch_size, 128, 128, 64]

encoder.add(layers.Conv2D(128, (3, 3), padding='same'))
encoder.add(layers.BatchNormalization())
encoder.add(layers.Activation('relu'))
encoder.add(layers.Conv2D(128, (3, 3), strides=2, padding='same'))
encoder.add(layers.BatchNormalization())
encoder.add(layers.Activation('relu')) # conv2: [batch_size, 64, 64, 128]

encoder.add(layers.Conv2D(256, (3, 3), padding='same'))
encoder.add(layers.BatchNormalization())
encoder.add(layers.Activation('relu'))
encoder.add(layers.Conv2D(256, (3, 3), strides=2, padding='same'))
encoder.add(layers.BatchNormalization())
encoder.add(layers.Activation('relu')) # conv3: [batch_size, 32, 32, 256]

encoder.add(layers.Conv2D(512, (3, 3), padding='same'))
encoder.add(layers.BatchNormalization())
encoder.add(layers.Activation('relu'))
encoder.add(layers.Conv2D(512, (3, 3), strides=2, padding='same'))
encoder.add(layers.BatchNormalization())
encoder.add(layers.Activation('relu')) # conv4-outputs: [batch_size, 16, 16, 512]

# %%
# Encoder 제대로 만들어졌는지 확인

bottleneck = encoder(tf.random.normal([batch_size, 256, 256, 3]))
print(bottleneck.shape)   # (batch_size, 16, 16, 512) 이 나오는지 확인
# Out:
# (8, 16, 16, 512)

# %%
# inputs: [batch_size, 16, 16, 512]
decoder = tf.keras.Sequential(name='decoder')

# conv_transpose-batchnorm-activation
decoder.add(layers.Conv2DTranspose(256, (3, 3), strides=2, padding='same'))
decoder.add(layers.BatchNormalization())
decoder.add(layers.Activation('relu')) # conv_transpose1: [batch_size, 32, 32, 256]
decoder.add(layers.Conv2D(256, (3, 3), padding='same'))
decoder.add(layers.BatchNormalization())
decoder.add(layers.Activation('relu'))

decoder.add(layers.Conv2DTranspose(128, (3, 3), strides=2, padding='same'))
decoder.add(layers.BatchNormalization())
decoder.add(layers.Activation('relu')) # conv_transpose2: [batch_size, 64, 64, 128]
decoder.add(layers.Conv2D(128, (3, 3), padding='same'))
decoder.add(layers.BatchNormalization())
decoder.add(layers.Activation('relu'))

decoder.add(layers.Conv2DTranspose(64, (3, 3), strides=2, padding='same'))
decoder.add(layers.BatchNormalization())
decoder.add(layers.Activation('relu')) # conv_transpose3: [batch_size, 128, 128, 64]
decoder.add(layers.Conv2D(64, (3, 3), padding='same'))
decoder.add(layers.BatchNormalization())
decoder.add(layers.Activation('relu'))

decoder.add(layers.Conv2DTranspose(32, (3, 3), strides=2, padding='same'))
decoder.add(layers.BatchNormalization())
decoder.add(layers.Activation('relu')) # conv transpose4-outputs: [batch_size, 256, 256, 32]
decoder.add(layers.Conv2D(32, (3, 3), padding='same'))
decoder.add(layers.BatchNormalization())
decoder.add(layers.Activation('relu'))

decoder.add(layers.Conv2DTranspose(1, 1, strides=1, padding='same', activation='sigmoid'))

# %%
# decoder 제대로 만들어졌는지 확인

predictions = decoder(bottleneck)
print(predictions.shape)    # (batch_size, 256, 256, 1) 이 나오는지 확인
# Out:
# (8, 256, 256, 1)

# %% [markdown]
# ### Create a encoder-decoder model
#
# 지금까지 Encoder와 Decoder를 잘 만들어 왔다면 이 둘을 결합한 모델은 다음과 같이 간단히 구성할 수 있습니다.

# %%
ed_model = tf.keras.Sequential()

ed_model.add(encoder)
ed_model.add(decoder)

# %%
class Conv(tf.keras.Model):
    def __init__(self, num_filters, kernel_size):
        super(Conv, self).__init__()
        self.conv = layers.Conv2D(num_filters, kernel_size, padding='same')
        self.bn = layers.BatchNormalization()

    def call(self, inputs, training=True):
        x = self.conv(inputs)
        x = self.bn(x, training=training)
        x = layers.ReLU()(x)

        return x

# %%
class ConvBlock(tf.keras.Model):
    def __init__(self, num_filters):
        super(ConvBlock, self).__init__()
        self.conv1 = Conv(num_filters, 3)
        self.conv2 = Conv(num_filters * 2, 3)

    def call(self, inputs, training=True):
        encoder = self.conv1(inputs, training=training)
        encoder = self.conv2(encoder, training=training)

        return encoder

class ConvBlock_R(tf.keras.Model):
    def __init__(self, num_filters):
        super(ConvBlock_R, self).__init__()
        self.conv1 = Conv(num_filters, 3)
        self.conv2 = Conv(num_filters, 3)

    def call(self, inputs, training=True):
        decoder = self.conv1(inputs, training=training)
        decoder = self.conv2(decoder, training=training)

        return decoder


class EncoderBlock(tf.keras.Model):
    def __init__(self, num_filters):
        super(EncoderBlock, self).__init__()
        self.conv_block = ConvBlock(num_filters)
        self.encoder_pool = layers.MaxPool2D()

    def call(self, inputs, training=True):
        encoder = self.conv_block(inputs, training=training)
        encoder_pool = self.encoder_pool(encoder)

        return encoder_pool, encoder


class DecoderBlock(tf.keras.Model):
    def __init__(self, num_filters):
        super(DecoderBlock, self).__init__()
        self.convT = layers.Conv2DTranspose(num_filters, 3, strides=2, padding='same')
        self.bn = layers.BatchNormalization()
        self.conv_block_r = ConvBlock_R(num_filters)

    def call(self, input_tensor, concat_tensor, training=True):
        decoder = self.convT(input_tensor)            
        decoder = self.bn(decoder, training=training)
        decoder = layers.ReLU()(decoder)
        decoder = tf.concat([decoder, concat_tensor], axis=-1)
        decoder = self.conv_block_r(decoder, training=training)

        return decoder

# %% [markdown]
# ### metrics과 loss functions 정의

# %%
def dice_coeff(y_true, y_pred):
    smooth = 1e-10
    # Flatten
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    score = (2. * intersection + smooth) / (tf.reduce_sum(tf.square(y_true_f)) + \
                                            tf.reduce_sum(tf.square(y_pred_f)) + smooth)

    return score

# %% [markdown]
#  * Dice Loss가 최대화되는 방향으로 구해지도록, 아래와 같이 사용

# %%
def dice_loss(y_true, y_pred):
    loss = 1 - dice_coeff(y_true, y_pred)
    return loss

# %% [markdown]
#  * 새로운 Loss function을 사용하기위해서 기존에 사용하였던 Binary crossentropy loss와 새로 구현한 Dice loss를 더하는 방식으로 구성

# %%
def bce_dice_loss(y_true, y_pred):
    loss = tf.reduce_mean(losses.binary_crossentropy(y_true, y_pred)) + \
          dice_loss(y_true, y_pred)
    return loss

# %%
optimizer = tf.keras.optimizers.Adam() # 기본 Learning rate 사용

# %% [markdown]
# ## Encoder-Decoder Model 학습 및 평가

# %%
print('select the Encoder-Decoder model')
model = ed_model
checkpoint_dir =os.path.join(DATASET_PATH,'train_ckpt/ed_model')
# Out:
# select the Encoder-Decoder model

# %%
model.compile(optimizer=optimizer, loss=bce_dice_loss, metrics=[dice_loss])
predictions = model(tf.random.normal([batch_size, image_size, image_size, 3]))
print(predictions.shape)
# Out:
# (8, 256, 256, 1)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder (Sequential)         (8, 16, 16, 512)          4693056
# _________________________________________________________________
# decoder (Sequential)         (8, 256, 256, 1)          2354913
# =================================================================
# Total params: 7,047,969
# Trainable params: 7,042,209
# Non-trainable params: 5,760
# _________________________________________________________________

# %% [markdown]
# ### Callbacks

# %%
if not os.path.isdir(checkpoint_dir):
    os.makedirs(checkpoint_dir)

cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_dir,
                                                 save_weights_only=True,
                                                 monitor='val_loss',
                                                 mode='auto',
                                                 save_best_only=True,
                                                 verbose=0)

# %%
cos_decay = tf.keras.experimental.CosineDecay(1e-3, 
                                              max_epochs)
lr_callback = tf.keras.callbacks.LearningRateScheduler(cos_decay, verbose=1)

# %%
## Define print function
def print_images():
    for test_images, test_labels in test_dataset.take(1):
        predictions = model(test_images, training=False)

        plt.figure(figsize=(10, 20))
        plt.subplot(1, 3, 1)
        plt.imshow(test_images[0,: , :, :])
        plt.title("Input image")

        plt.subplot(1, 3, 2)
        plt.imshow(test_labels[0, :, :, 0])
        plt.title("Actual Mask")

        plt.subplot(1, 3, 3)
        plt.imshow(predictions[0, :, :, 0])
        plt.title("Predicted Mask")
        plt.show()

# %%
history = model.fit(train_dataset,
                    epochs=max_epochs,    # 50
                    steps_per_epoch=num_train_examples//batch_size,
                    validation_data=test_dataset,
                    validation_steps=num_test_examples//batch_size,
                    callbacks=[cp_callback, lr_callback]
                    )
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to tf.Tensor(0.001, shape=(), dtype=float32).
# Epoch 1/50
#  2/60 [>.............................] - ETA: 4s - loss: 1.6409 - dice_loss: 0.8662WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0560s vs `on_train_batch_end` time: 0.0895s). Check your callbacks.
# 60/60 [==============================] - ETA: 0s - loss: 1.0920 - dice_loss: 0.7489WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0022s vs `on_test_batch_end` time: 0.0360s). Check your callbacks.
# 60/60 [==============================] - 8s 139ms/step - loss: 1.0920 - dice_loss: 0.7489 - val_loss: 1.2463 - val_dice_loss: 0.8596
#
# Epoch 00002: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009990134, shape=(), dtype=float32).
# Epoch 2/50
# 60/60 [==============================] - 8s 135ms/step - loss: 0.9401 - dice_loss: 0.7099 - val_loss: 1.2092 - val_dice_loss: 0.7800
#
# Epoch 00003: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009960574, shape=(), dtype=float32).
# Epoch 3/50
# 60/60 [==============================] - 8s 136ms/step - loss: 0.9015 - dice_loss: 0.6859 - val_loss: 1.0929 - val_dice_loss: 0.8233
#
# Epoch 00004: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009911436, shape=(), dtype=float32).
# Epoch 4/50
# 60/60 [==============================] - 8s 136ms/step - loss: 0.8138 - dice_loss: 0.6203 - val_loss: 1.0455 - val_dice_loss: 0.8032
#
# Epoch 00005: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009842915, shape=(), dtype=float32).
# Epoch 5/50
# 60/60 [==============================] - 8s 137ms/step - loss: 0.7174 - dice_loss: 0.5460 - val_loss: 0.9747 - val_dice_loss: 0.7009
#
# Epoch 00006: LearningRateScheduler reducing learning rate to tf.Tensor(0.00097552827, shape=(), dtype=float32).
# Epoch 6/50
# 60/60 [==============================] - 8s 134ms/step - loss: 0.6571 - dice_loss: 0.4994 - val_loss: 1.0605 - val_dice_loss: 0.6520
#
# Epoch 00007: LearningRateScheduler reducing learning rate to tf.Tensor(0.00096488826, shape=(), dtype=float32).
# Epoch 7/50
# 60/60 [==============================] - 8s 134ms/step - loss: 0.5616 - dice_loss: 0.4245 - val_loss: 1.0960 - val_dice_loss: 0.9017
#
# Epoch 00008: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009524136, shape=(), dtype=float32).
# Epoch 8/50
# 60/60 [==============================] - 8s 137ms/step - loss: 0.4955 - dice_loss: 0.3751 - val_loss: 0.5230 - val_dice_loss: 0.4119
#
# Epoch 00009: LearningRateScheduler reducing learning rate to tf.Tensor(0.00093815336, shape=(), dtype=float32).
# Epoch 9/50
# 60/60 [==============================] - 8s 137ms/step - loss: 0.4264 - dice_loss: 0.3197 - val_loss: 0.4988 - val_dice_loss: 0.3804
#
# Epoch 00010: LearningRateScheduler reducing learning rate to tf.Tensor(0.000922164, shape=(), dtype=float32).
# Epoch 10/50
# 60/60 [==============================] - 8s 138ms/step - loss: 0.4165 - dice_loss: 0.3129 - val_loss: 0.4550 - val_dice_loss: 0.3293
#
# Epoch 00011: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009045085, shape=(), dtype=float32).
# Epoch 11/50
# 60/60 [==============================] - 8s 135ms/step - loss: 0.3586 - dice_loss: 0.2668 - val_loss: 0.5669 - val_dice_loss: 0.4452
#
# Epoch 00012: LearningRateScheduler reducing learning rate to tf.Tensor(0.0008852567, shape=(), dtype=float32).
# Epoch 12/50
# 60/60 [==============================] - 8s 138ms/step - loss: 0.3345 - dice_loss: 0.2497 - val_loss: 0.4537 - val_dice_loss: 0.3415
#
# Epoch 00013: LearningRateScheduler reducing learning rate to tf.Tensor(0.00086448435, shape=(), dtype=float32).
# Epoch 13/50
# 60/60 [==============================] - 8s 138ms/step - loss: 0.2996 - dice_loss: 0.2224 - val_loss: 0.3715 - val_dice_loss: 0.2838
#
# Epoch 00014: LearningRateScheduler reducing learning rate to tf.Tensor(0.00084227364, shape=(), dtype=float32).
# Epoch 14/50
# 60/60 [==============================] - 8s 135ms/step - loss: 0.2984 - dice_loss: 0.2213 - val_loss: 0.4660 - val_dice_loss: 0.3706
#
# Epoch 00015: LearningRateScheduler reducing learning rate to tf.Tensor(0.00081871205, shape=(), dtype=float32).
# Epoch 15/50
# 60/60 [==============================] - 8s 138ms/step - loss: 0.2751 - dice_loss: 0.2039 - val_loss: 0.3339 - val_dice_loss: 0.2528
#
# Epoch 00016: LearningRateScheduler reducing learning rate to tf.Tensor(0.00079389266, shape=(), dtype=float32).
# Epoch 16/50
# 60/60 [==============================] - 8s 135ms/step - loss: 0.2533 - dice_loss: 0.1871 - val_loss: 0.4657 - val_dice_loss: 0.3541
#
# Epoch 00017: LearningRateScheduler reducing learning rate to tf.Tensor(0.00076791336, shape=(), dtype=float32).
# Epoch 17/50
# 60/60 [==============================] - 8s 138ms/step - loss: 0.2450 - dice_loss: 0.1803 - val_loss: 0.2849 - val_dice_loss: 0.2161
#
# Epoch 00018: LearningRateScheduler reducing learning rate to tf.Tensor(0.0007408768, shape=(), dtype=float32).
# Epoch 18/50
# 60/60 [==============================] - 8s 135ms/step - loss: 0.2317 - dice_loss: 0.1717 - val_loss: 0.3155 - val_dice_loss: 0.2402
#
# Epoch 00019: LearningRateScheduler reducing learning rate to tf.Tensor(0.00071288965, shape=(), dtype=float32).
# Epoch 19/50
# 60/60 [==============================] - 8s 135ms/step - loss: 0.2164 - dice_loss: 0.1603 - val_loss: 0.3851 - val_dice_loss: 0.2974
#
# Epoch 00020: LearningRateScheduler reducing learning rate to tf.Tensor(0.00068406225, shape=(), dtype=float32).
# Epoch 20/50
# 60/60 [==============================] - 8s 138ms/step - loss: 0.2035 - dice_loss: 0.1496 - val_loss: 0.2405 - val_dice_loss: 0.1839
#
# Epoch 00021: LearningRateScheduler reducing learning rate to tf.Tensor(0.0006545085, shape=(), dtype=float32).
# Epoch 21/50
# 60/60 [==============================] - 8s 135ms/step - loss: 0.1841 - dice_loss: 0.1346 - val_loss: 0.3020 - val_dice_loss: 0.2310
#
# Epoch 00022: LearningRateScheduler reducing learning rate to tf.Tensor(0.00062434503, shape=(), dtype=float32).
# Epoch 22/50
# 60/60 [==============================] - 8s 136ms/step - loss: 0.1790 - dice_loss: 0.1308 - val_loss: 0.3655 - val_dice_loss: 0.2831
#
# Epoch 00023: LearningRateScheduler reducing learning rate to tf.Tensor(0.00059369067, shape=(), dtype=float32).
# Epoch 23/50
# 60/60 [==============================] - 8s 138ms/step - loss: 0.1844 - dice_loss: 0.1356 - val_loss: 0.2272 - val_dice_loss: 0.1719
#
# Epoch 00024: LearningRateScheduler reducing learning rate to tf.Tensor(0.00056266657, shape=(), dtype=float32).
# Epoch 24/50
# 60/60 [==============================] - 8s 139ms/step - loss: 0.1681 - dice_loss: 0.1232 - val_loss: 0.2001 - val_dice_loss: 0.1509
#
# Epoch 00025: LearningRateScheduler reducing learning rate to tf.Tensor(0.00053139526, shape=(), dtype=float32).
# Epoch 25/50
# 60/60 [==============================] - 8s 139ms/step - loss: 0.1483 - dice_loss: 0.1078 - val_loss: 0.1783 - val_dice_loss: 0.1334
#
# Epoch 00026: LearningRateScheduler reducing learning rate to tf.Tensor(0.00049999997, shape=(), dtype=float32).
# Epoch 26/50
# 60/60 [==============================] - 8s 136ms/step - loss: 0.1350 - dice_loss: 0.0985 - val_loss: 0.1891 - val_dice_loss: 0.1424
#
# Epoch 00027: LearningRateScheduler reducing learning rate to tf.Tensor(0.0004686048, shape=(), dtype=float32).
# Epoch 27/50
# 60/60 [==============================] - 8s 136ms/step - loss: 0.1484 - dice_loss: 0.1081 - val_loss: 0.2079 - val_dice_loss: 0.1545
#
# Epoch 00028: LearningRateScheduler reducing learning rate to tf.Tensor(0.00043733336, shape=(), dtype=float32).
# Epoch 28/50
# 60/60 [==============================] - 8s 139ms/step - loss: 0.1437 - dice_loss: 0.1051 - val_loss: 0.1753 - val_dice_loss: 0.1322
#
# Epoch 00029: LearningRateScheduler reducing learning rate to tf.Tensor(0.00040630935, shape=(), dtype=float32).
# Epoch 29/50
# 60/60 [==============================] - 8s 139ms/step - loss: 0.1218 - dice_loss: 0.0886 - val_loss: 0.1683 - val_dice_loss: 0.1262
#
# Epoch 00030: LearningRateScheduler reducing learning rate to tf.Tensor(0.00037565507, shape=(), dtype=float32).
# Epoch 30/50
# 60/60 [==============================] - 8s 138ms/step - loss: 0.1195 - dice_loss: 0.0881 - val_loss: 0.1333 - val_dice_loss: 0.0985
# Epoch 00031: LearningRateScheduler reducing learning rate to tf.Tensor(0.00034549143, shape=(), dtype=float32).
# Epoch 31/50
# 60/60 [==============================] - 8s 136ms/step - loss: 0.1004 - dice_loss: 0.0725 - val_loss: 0.1490 - val_dice_loss: 0.1099
#
# Epoch 00032: LearningRateScheduler reducing learning rate to tf.Tensor(0.0003159377, shape=(), dtype=float32).
# Epoch 32/50
# 60/60 [==============================] - 8s 136ms/step - loss: 0.1080 - dice_loss: 0.0781 - val_loss: 0.1367 - val_dice_loss: 0.1010
#
# Epoch 00033: LearningRateScheduler reducing learning rate to tf.Tensor(0.00028711034, shape=(), dtype=float32).
# Epoch 33/50
# 60/60 [==============================] - 8s 135ms/step - loss: 0.1046 - dice_loss: 0.0763 - val_loss: 0.1729 - val_dice_loss: 0.1287
#
# Epoch 00034: LearningRateScheduler reducing learning rate to tf.Tensor(0.0002591231, shape=(), dtype=float32).
# Epoch 34/50
# 60/60 [==============================] - 8s 138ms/step - loss: 0.1002 - dice_loss: 0.0730 - val_loss: 0.1226 - val_dice_loss: 0.0903
#
# Epoch 00035: LearningRateScheduler reducing learning rate to tf.Tensor(0.00023208655, shape=(), dtype=float32).
# Epoch 35/50
# 60/60 [==============================] - 8s 139ms/step - loss: 0.0890 - dice_loss: 0.0644 - val_loss: 0.1192 - val_dice_loss: 0.0880
#
# Epoch 00036: LearningRateScheduler reducing learning rate to tf.Tensor(0.00020610739, shape=(), dtype=float32).
# Epoch 36/50
# 60/60 [==============================] - 8s 139ms/step - loss: 0.0858 - dice_loss: 0.0621 - val_loss: 0.1169 - val_dice_loss: 0.0855
#
# Epoch 00037: LearningRateScheduler reducing learning rate to tf.Tensor(0.00018128792, shape=(), dtype=float32).
# Epoch 37/50
# 60/60 [==============================] - 8s 136ms/step - loss: 0.0858 - dice_loss: 0.0622 - val_loss: 0.1315 - val_dice_loss: 0.0974
#
# Epoch 00038: LearningRateScheduler reducing learning rate to tf.Tensor(0.00015772645, shape=(), dtype=float32).
# Epoch 38/50
# 60/60 [==============================] - 8s 139ms/step - loss: 0.0840 - dice_loss: 0.0611 - val_loss: 0.1112 - val_dice_loss: 0.0812
#
# Epoch 00039: LearningRateScheduler reducing learning rate to tf.Tensor(0.0001355157, shape=(), dtype=float32).
# Epoch 39/50
# 60/60 [==============================] - 8s 136ms/step - loss: 0.0788 - dice_loss: 0.0572 - val_loss: 0.1144 - val_dice_loss: 0.0838
#
# Epoch 00040: LearningRateScheduler reducing learning rate to tf.Tensor(0.00011474339, shape=(), dtype=float32).
# Epoch 40/50
# 60/60 [==============================] - 8s 136ms/step - loss: 0.0824 - dice_loss: 0.0604 - val_loss: 0.1121 - val_dice_loss: 0.0824
#
# Epoch 00041: LearningRateScheduler reducing learning rate to tf.Tensor(9.54915e-05, shape=(), dtype=float32).
# Epoch 41/50
# 60/60 [==============================] - 8s 136ms/step - loss: 0.0743 - dice_loss: 0.0537 - val_loss: 0.1132 - val_dice_loss: 0.0831
#
# Epoch 00042: LearningRateScheduler reducing learning rate to tf.Tensor(7.783601e-05, shape=(), dtype=float32).
# Epoch 42/50
# 60/60 [==============================] - 8s 138ms/step - loss: 0.0734 - dice_loss: 0.0531 - val_loss: 0.1054 - val_dice_loss: 0.0770
#
# Epoch 00043: LearningRateScheduler reducing learning rate to tf.Tensor(6.184671e-05, shape=(), dtype=float32).
# Epoch 43/50
# 60/60 [==============================] - 8s 138ms/step - loss: 0.0706 - dice_loss: 0.0512 - val_loss: 0.1025 - val_dice_loss: 0.0746
#
# Epoch 00044: LearningRateScheduler reducing learning rate to tf.Tensor(4.7586444e-05, shape=(), dtype=float32).
# Epoch 44/50
# 60/60 [==============================] - 8s 136ms/step - loss: 0.0704 - dice_loss: 0.0510 - val_loss: 0.1052 - val_dice_loss: 0.0769
#
# Epoch 00045: LearningRateScheduler reducing learning rate to tf.Tensor(3.5111727e-05, shape=(), dtype=float32).
# Epoch 45/50
# 60/60 [==============================] - 8s 138ms/step - loss: 0.0704 - dice_loss: 0.0508 - val_loss: 0.1020 - val_dice_loss: 0.0746
#
# Epoch 00046: LearningRateScheduler reducing learning rate to tf.Tensor(2.4471761e-05, shape=(), dtype=float32).
# Epoch 46/50
# 60/60 [==============================] - 8s 139ms/step - loss: 0.0712 - dice_loss: 0.0517 - val_loss: 0.1014 - val_dice_loss: 0.0740
#
# Epoch 00047: LearningRateScheduler reducing learning rate to tf.Tensor(1.5708387e-05, shape=(), dtype=float32).
# Epoch 47/50
# 60/60 [==============================] - 8s 136ms/step - loss: 0.0697 - dice_loss: 0.0504 - val_loss: 0.1018 - val_dice_loss: 0.0743
#
# Epoch 00048: LearningRateScheduler reducing learning rate to tf.Tensor(8.856387e-06, shape=(), dtype=float32).
# Epoch 48/50
# 60/60 [==============================] - 8s 139ms/step - loss: 0.0671 - dice_loss: 0.0486 - val_loss: 0.1003 - val_dice_loss: 0.0731
#
# Epoch 00049: LearningRateScheduler reducing learning rate to tf.Tensor(3.9426386e-06, shape=(), dtype=float32).
# Epoch 49/50
# 60/60 [==============================] - 8s 139ms/step - loss: 0.0707 - dice_loss: 0.0511 - val_loss: 0.0998 - val_dice_loss: 0.0728
#
# Epoch 00050: LearningRateScheduler reducing learning rate to tf.Tensor(9.866358e-07, shape=(), dtype=float32).
# Epoch 50/50
# 60/60 [==============================] - 8s 139ms/step - loss: 0.0677 - dice_loss: 0.0490 - val_loss: 0.0997 - val_dice_loss: 0.0727

# %%
# print sample image after training
print_images()

# %% [markdown]
# ### Plot the loss
#
# 저장된 학습 진행과정(history)을 시각화

# %%
dice_loss = history.history['dice_loss']
loss = history.history['loss']
val_dice_loss = history.history['val_dice_loss']
val_loss = history.history['val_loss']

epochs_range = range(max_epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, loss, label='Loss')
plt.plot(epochs_range, dice_loss, label='Dice Loss')
plt.legend(loc='upper right')
plt.title('Train Loss')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, val_loss, label='Val Loss')
plt.plot(epochs_range, val_dice_loss, label='Val Dice Loss')
plt.legend(loc='upper right')
plt.title('Valid Loss')
plt.show()

# %% [markdown]
# ### Restore the latest checkpoint
#
#  - 저장된 모델의 가중치를 불러오기

# %%
# restoring the latest checkpoint in checkpoint_dir
model.load_weights(checkpoint_dir)

# %% [markdown]
# ### Evaluate the test dataset
#
# 불러온 가중치를 이용해서 모델을 평가

# %%
def mean_iou(y_true, y_pred, num_classes=2):
    # Flatten  
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])

    y_true_f = tf.cast(tf.round(y_true_f), dtype=tf.int32).numpy()
    y_pred_f = tf.cast(tf.round(y_pred_f), dtype=tf.int32).numpy()

    # calculate confusion matrix
    labels = list(range(num_classes))
    current = confusion_matrix(y_true_f, y_pred_f, labels=labels)

    # compute mean iou
    intersection = np.diag(current)
    ground_truth_set = current.sum(axis=1)
    predicted_set = current.sum(axis=0)
    union = ground_truth_set + predicted_set - intersection

    IoU = intersection / union.astype(np.float32)
    return np.mean(IoU)

# %% [markdown]
#  * 테스트 데이터셋을 불러와서 meanIoU 값을 구해보기

# %%
mean = []

for images, labels in test_dataset:
    predictions = model(images, training=False)
    m = mean_iou(labels, predictions)
    mean.append(m)

mean = np.array(mean)
mean = np.mean(mean)
print("mean_iou: {}".format(mean))
# Out:
# mean_iou: 0.909351811217343

# %% [markdown]
#  * Test Dataset 내에 데이터들을 얼만큼 잘 맞추었는지 직접 확인

# %%
## Define print function
def print_images():
    for test_images, test_labels in test_dataset.take(1):
        predictions = model(test_images, training=False)

        for i in range(batch_size):
            plt.figure(figsize=(10, 20))
            plt.subplot(1, 3, 1)
            plt.imshow(test_images[i,: , :, :])
            plt.title("Input image")

            plt.subplot(1, 3, 2)
            plt.imshow(test_labels[i, :, :, 0])
            plt.title("Actual Mask")

            plt.subplot(1, 3, 3)
            plt.imshow(predictions[i, :, :, 0])
            plt.title("Predicted Mask")
            plt.show()

# %%
print_images()

# %% [markdown]
# ## U-Net Model 학습 및 평가

# %% [markdown]
# ### U-NET model 생성

# %%
class UNet(tf.keras.Model):
    def __init__(self):
        super(UNet, self).__init__()
        self.encoder_block1 = EncoderBlock(64)
        self.encoder_block2 = EncoderBlock(128)
        self.encoder_block3 = EncoderBlock(256)
        self.encoder_block4 = EncoderBlock(512)

        self.center = ConvBlock(1024)

        self.decoder_block4 = DecoderBlock(512)
        self.decoder_block3 = DecoderBlock(256)
        self.decoder_block2 = DecoderBlock(128)
        self.decoder_block1 = DecoderBlock(64)

        self.output_conv = layers.Conv2D(1, 1, activation='sigmoid')

    def call(self, inputs, training=True):
        encoder1_pool, encoder1 = self.encoder_block1(inputs)
        encoder2_pool, encoder2 = self.encoder_block2(encoder1_pool)
        encoder3_pool, encoder3 = self.encoder_block3(encoder2_pool)
        encoder4_pool, encoder4 = self.encoder_block4(encoder3_pool)

        center = self.center(encoder4_pool)

        decoder4 = self.decoder_block4(center, encoder4)
        decoder3 = self.decoder_block3(decoder4, encoder3)
        decoder2 = self.decoder_block2(decoder3, encoder2)
        decoder1 = self.decoder_block1(decoder2, encoder1)

        outputs = self.output_conv(decoder1)

        return outputs

# %% [markdown]
# ### Create a U-Net model

# %%
unet_model = UNet()

# %%
def dice_coeff(y_true, y_pred):
    smooth = 1e-10
    # Flatten
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    score = (2. * intersection + smooth) / (tf.reduce_sum(tf.square(y_true_f)) + \
                                            tf.reduce_sum(tf.square(y_pred_f)) + smooth)

    return score

# %%
def dice_loss(y_true, y_pred):
    loss = 1 - dice_coeff(y_true, y_pred)
    return loss

# %%
def bce_dice_loss(y_true, y_pred):
    loss = tf.reduce_mean(losses.binary_crossentropy(y_true, y_pred)) + \
          dice_loss(y_true, y_pred)
    return loss

# %%
optimizer = tf.keras.optimizers.Adam() # 기본 Learning rate 사용

# %%
print('select the U-Net model')
model = unet_model
checkpoint_dir =os.path.join(DATASET_PATH,'train_ckpt/unet_model')
# Out:
# select the U-Net model

# %% [markdown]
# ### Compile

# %%
model.compile(optimizer=optimizer, loss=bce_dice_loss, metrics=[dice_loss])
predictions = model(tf.random.normal([batch_size, image_size, image_size, 3]))
print(predictions.shape)
# Out:
# (8, 256, 256, 1)

# %%
model.summary()
# Out:
# Model: "u_net_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_block_4 (EncoderBloc multiple                  76416
# _________________________________________________________________
# encoder_block_5 (EncoderBloc multiple                  444288
# _________________________________________________________________
# encoder_block_6 (EncoderBloc multiple                  1773312
# _________________________________________________________________
# encoder_block_7 (EncoderBloc multiple                  7085568
# _________________________________________________________________
# conv_block_9 (ConvBlock)     multiple                  28326912
# _________________________________________________________________
# decoder_block_4 (DecoderBloc multiple                  18882048
# _________________________________________________________________
# decoder_block_5 (DecoderBloc multiple                  3542784
# _________________________________________________________________
# decoder_block_6 (DecoderBloc multiple                  886656
# _________________________________________________________________
# decoder_block_7 (DecoderBloc multiple                  222144
# _________________________________________________________________
# conv2d_49 (Conv2D)           multiple                  65
# =================================================================
# Total params: 61,240,193
# Trainable params: 61,222,529
# Non-trainable params: 17,664
# _________________________________________________________________

# %% [markdown]
# ### Callbacks

# %%
if not os.path.isdir(checkpoint_dir):
    os.makedirs(checkpoint_dir)

cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_dir,
                                                 save_weights_only=True,
                                                 monitor='val_loss',
                                                 mode='auto',
                                                 save_best_only=True,
                                                 verbose=0)

# %%
cos_decay = tf.keras.experimental.CosineDecay(1e-3, 
                                              max_epochs)
lr_callback = tf.keras.callbacks.LearningRateScheduler(cos_decay, verbose=1)

# %%
## Define print function
def print_images():
    for test_images, test_labels in test_dataset.take(1):
        predictions = model(test_images, training=False)

        plt.figure(figsize=(10, 20))
        plt.subplot(1, 3, 1)
        plt.imshow(test_images[0,: , :, :])
        plt.title("Input image")

        plt.subplot(1, 3, 2)
        plt.imshow(test_labels[0, :, :, 0])
        plt.title("Actual Mask")

        plt.subplot(1, 3, 3)
        plt.imshow(predictions[0, :, :, 0])
        plt.title("Predicted Mask")
        plt.show()

# %%
history = model.fit(train_dataset,
                    epochs=max_epochs,    # 50
                    steps_per_epoch=num_train_examples//batch_size,
                    validation_data=test_dataset,
                    validation_steps=num_test_examples//batch_size,
                    callbacks=[cp_callback, lr_callback]
                    )
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to tf.Tensor(0.001, shape=(), dtype=float32).
# Epoch 1/50
#  2/60 [>.............................] - ETA: 15s - loss: 1.3198 - dice_loss: 0.7608WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2008s vs `on_train_batch_end` time: 0.3339s). Check your callbacks.
# 60/60 [==============================] - ETA: 0s - loss: 0.9370 - dice_loss: 0.6935WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0038s vs `on_test_batch_end` time: 0.1716s). Check your callbacks.
# 60/60 [==============================] - 35s 589ms/step - loss: 0.9370 - dice_loss: 0.6935 - val_loss: 772.1425 - val_dice_loss: 1.0000
#
# Epoch 00002: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009990134, shape=(), dtype=float32).
# Epoch 2/50
# 60/60 [==============================] - 35s 588ms/step - loss: 0.8128 - dice_loss: 0.6228 - val_loss: 436.1606 - val_dice_loss: 1.0000
#
# Epoch 00003: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009960574, shape=(), dtype=float32).
# Epoch 3/50
# 60/60 [==============================] - 34s 574ms/step - loss: 0.6431 - dice_loss: 0.4885 - val_loss: 463.8942 - val_dice_loss: 0.9056
#
# Epoch 00004: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009911436, shape=(), dtype=float32).
# Epoch 4/50
# 60/60 [==============================] - 36s 592ms/step - loss: 0.5795 - dice_loss: 0.4400 - val_loss: 220.1216 - val_dice_loss: 0.9050
#
# Epoch 00005: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009842915, shape=(), dtype=float32).
# Epoch 5/50
# 60/60 [==============================] - 36s 598ms/step - loss: 0.5037 - dice_loss: 0.3802 - val_loss: 7.0288 - val_dice_loss: 0.8548
#
# Epoch 00006: LearningRateScheduler reducing learning rate to tf.Tensor(0.00097552827, shape=(), dtype=float32).
# Epoch 6/50
# 60/60 [==============================] - 36s 596ms/step - loss: 0.4698 - dice_loss: 0.3555 - val_loss: 6.8108 - val_dice_loss: 0.8598
#
# Epoch 00007: LearningRateScheduler reducing learning rate to tf.Tensor(0.00096488826, shape=(), dtype=float32).
# Epoch 7/50
# 60/60 [==============================] - 36s 594ms/step - loss: 0.3992 - dice_loss: 0.2998 - val_loss: 0.6810 - val_dice_loss: 0.5010
#
# Epoch 00008: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009524136, shape=(), dtype=float32).
# Epoch 8/50
# 60/60 [==============================] - 36s 597ms/step - loss: 0.3844 - dice_loss: 0.2885 - val_loss: 0.4488 - val_dice_loss: 0.3220
#
# Epoch 00009: LearningRateScheduler reducing learning rate to tf.Tensor(0.00093815336, shape=(), dtype=float32).
# Epoch 9/50
# 60/60 [==============================] - 35s 576ms/step - loss: 0.3373 - dice_loss: 0.2530 - val_loss: 0.4930 - val_dice_loss: 0.3741
#
# Epoch 00010: LearningRateScheduler reducing learning rate to tf.Tensor(0.000922164, shape=(), dtype=float32).
# Epoch 10/50
# 60/60 [==============================] - 36s 595ms/step - loss: 0.3167 - dice_loss: 0.2366 - val_loss: 0.3806 - val_dice_loss: 0.2801
#
# Epoch 00011: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009045085, shape=(), dtype=float32).
# Epoch 11/50
# 60/60 [==============================] - 35s 577ms/step - loss: 0.2755 - dice_loss: 0.2046 - val_loss: 0.4679 - val_dice_loss: 0.3684
#
# Epoch 00012: LearningRateScheduler reducing learning rate to tf.Tensor(0.0008852567, shape=(), dtype=float32).
# Epoch 12/50
# 60/60 [==============================] - 35s 577ms/step - loss: 0.2425 - dice_loss: 0.1798 - val_loss: 0.5951 - val_dice_loss: 0.4758
#
# Epoch 00013: LearningRateScheduler reducing learning rate to tf.Tensor(0.00086448435, shape=(), dtype=float32).
# Epoch 13/50
# 60/60 [==============================] - 35s 576ms/step - loss: 0.2533 - dice_loss: 0.1887 - val_loss: 0.3824 - val_dice_loss: 0.2912
#
# Epoch 00014: LearningRateScheduler reducing learning rate to tf.Tensor(0.00084227364, shape=(), dtype=float32).
# Epoch 14/50
# 60/60 [==============================] - 35s 576ms/step - loss: 0.2590 - dice_loss: 0.1934 - val_loss: 0.9640 - val_dice_loss: 0.7721
#
# Epoch 00015: LearningRateScheduler reducing learning rate to tf.Tensor(0.00081871205, shape=(), dtype=float32).
# Epoch 15/50
# 60/60 [==============================] - 35s 579ms/step - loss: 0.2133 - dice_loss: 0.1572 - val_loss: 0.7065 - val_dice_loss: 0.5531
#
# Epoch 00016: LearningRateScheduler reducing learning rate to tf.Tensor(0.00079389266, shape=(), dtype=float32).
# Epoch 16/50
# 60/60 [==============================] - 36s 594ms/step - loss: 0.1854 - dice_loss: 0.1360 - val_loss: 0.3651 - val_dice_loss: 0.2765
#
# Epoch 00017: LearningRateScheduler reducing learning rate to tf.Tensor(0.00076791336, shape=(), dtype=float32).
# Epoch 17/50
# 60/60 [==============================] - 36s 594ms/step - loss: 0.1708 - dice_loss: 0.1248 - val_loss: 0.2491 - val_dice_loss: 0.1840
#
# Epoch 00018: LearningRateScheduler reducing learning rate to tf.Tensor(0.0007408768, shape=(), dtype=float32).
# Epoch 18/50
# 60/60 [==============================] - 36s 594ms/step - loss: 0.1666 - dice_loss: 0.1220 - val_loss: 0.2399 - val_dice_loss: 0.1781
#
# Epoch 00019: LearningRateScheduler reducing learning rate to tf.Tensor(0.00071288965, shape=(), dtype=float32).
# Epoch 19/50
# 60/60 [==============================] - 35s 577ms/step - loss: 0.1495 - dice_loss: 0.1097 - val_loss: 0.4397 - val_dice_loss: 0.3422
#
# Epoch 00020: LearningRateScheduler reducing learning rate to tf.Tensor(0.00068406225, shape=(), dtype=float32).
# Epoch 20/50
# 60/60 [==============================] - 36s 597ms/step - loss: 0.1418 - dice_loss: 0.1040 - val_loss: 0.2130 - val_dice_loss: 0.1563
#
# Epoch 00021: LearningRateScheduler reducing learning rate to tf.Tensor(0.0006545085, shape=(), dtype=float32).
# Epoch 21/50
# 60/60 [==============================] - 36s 594ms/step - loss: 0.1267 - dice_loss: 0.0917 - val_loss: 0.2063 - val_dice_loss: 0.1552
#
# Epoch 00022: LearningRateScheduler reducing learning rate to tf.Tensor(0.00062434503, shape=(), dtype=float32).
# Epoch 22/50
# 60/60 [==============================] - 35s 577ms/step - loss: 0.1288 - dice_loss: 0.0940 - val_loss: 0.2141 - val_dice_loss: 0.1556
#
# Epoch 00023: LearningRateScheduler reducing learning rate to tf.Tensor(0.00059369067, shape=(), dtype=float32).
# Epoch 23/50
# 60/60 [==============================] - 36s 594ms/step - loss: 0.1316 - dice_loss: 0.0968 - val_loss: 0.1549 - val_dice_loss: 0.1150
#
# Epoch 00024: LearningRateScheduler reducing learning rate to tf.Tensor(0.00056266657, shape=(), dtype=float32).
# Epoch 24/50
# 60/60 [==============================] - 35s 576ms/step - loss: 0.1184 - dice_loss: 0.0860 - val_loss: 0.1575 - val_dice_loss: 0.1146
#
# Epoch 00025: LearningRateScheduler reducing learning rate to tf.Tensor(0.00053139526, shape=(), dtype=float32).
# Epoch 25/50
# 60/60 [==============================] - 35s 576ms/step - loss: 0.1348 - dice_loss: 0.0985 - val_loss: 0.1792 - val_dice_loss: 0.1308
#
# Epoch 00026: LearningRateScheduler reducing learning rate to tf.Tensor(0.00049999997, shape=(), dtype=float32).
# Epoch 26/50
# 60/60 [==============================] - 35s 575ms/step - loss: 0.1221 - dice_loss: 0.0890 - val_loss: 0.1828 - val_dice_loss: 0.1367
#
# Epoch 00027: LearningRateScheduler reducing learning rate to tf.Tensor(0.0004686048, shape=(), dtype=float32).
# Epoch 27/50
# 60/60 [==============================] - 36s 594ms/step - loss: 0.1030 - dice_loss: 0.0748 - val_loss: 0.1543 - val_dice_loss: 0.1133
#
# Epoch 00028: LearningRateScheduler reducing learning rate to tf.Tensor(0.00043733336, shape=(), dtype=float32).
# Epoch 28/50
# 60/60 [==============================] - 36s 595ms/step - loss: 0.1013 - dice_loss: 0.0738 - val_loss: 0.1497 - val_dice_loss: 0.1108
#
# Epoch 00029: LearningRateScheduler reducing learning rate to tf.Tensor(0.00040630935, shape=(), dtype=float32).
# Epoch 29/50
# 60/60 [==============================] - 36s 594ms/step - loss: 0.0843 - dice_loss: 0.0609 - val_loss: 0.1349 - val_dice_loss: 0.1004
#
# Epoch 00030: LearningRateScheduler reducing learning rate to tf.Tensor(0.00037565507, shape=(), dtype=float32).
# Epoch 30/50
# 60/60 [==============================] - 36s 593ms/step - loss: 0.0814 - dice_loss: 0.0589 - val_loss: 0.1263 - val_dice_loss: 0.0950
#
# Epoch 00031: LearningRateScheduler reducing learning rate to tf.Tensor(0.00034549143, shape=(), dtype=float32).
# Epoch 31/50
# 60/60 [==============================] - 36s 595ms/step - loss: 0.0764 - dice_loss: 0.0552 - val_loss: 0.1147 - val_dice_loss: 0.0851
#
# Epoch 00032: LearningRateScheduler reducing learning rate to tf.Tensor(0.0003159377, shape=(), dtype=float32).
# Epoch 32/50
# 60/60 [==============================] - 36s 598ms/step - loss: 0.0796 - dice_loss: 0.0578 - val_loss: 0.1106 - val_dice_loss: 0.0819
#
# Epoch 00033: LearningRateScheduler reducing learning rate to tf.Tensor(0.00028711034, shape=(), dtype=float32).
# Epoch 33/50
# 60/60 [==============================] - 36s 595ms/step - loss: 0.0730 - dice_loss: 0.0526 - val_loss: 0.1101 - val_dice_loss: 0.0818
#
# Epoch 00034: LearningRateScheduler reducing learning rate to tf.Tensor(0.0002591231, shape=(), dtype=float32).
# Epoch 34/50
# 60/60 [==============================] - 36s 594ms/step - loss: 0.0709 - dice_loss: 0.0512 - val_loss: 0.0901 - val_dice_loss: 0.0661
#
# Epoch 00035: LearningRateScheduler reducing learning rate to tf.Tensor(0.00023208655, shape=(), dtype=float32).
# Epoch 35/50
# 60/60 [==============================] - 36s 596ms/step - loss: 0.0660 - dice_loss: 0.0481 - val_loss: 0.0852 - val_dice_loss: 0.0627
#
# Epoch 00036: LearningRateScheduler reducing learning rate to tf.Tensor(0.00020610739, shape=(), dtype=float32).
# Epoch 36/50
# 60/60 [==============================] - 35s 577ms/step - loss: 0.0661 - dice_loss: 0.0481 - val_loss: 0.0978 - val_dice_loss: 0.0725
#
# Epoch 00037: LearningRateScheduler reducing learning rate to tf.Tensor(0.00018128792, shape=(), dtype=float32).
# Epoch 37/50
# 60/60 [==============================] - 36s 596ms/step - loss: 0.0619 - dice_loss: 0.0447 - val_loss: 0.0822 - val_dice_loss: 0.0601
#
# Epoch 00038: LearningRateScheduler reducing learning rate to tf.Tensor(0.00015772645, shape=(), dtype=float32).
# Epoch 38/50
# 60/60 [==============================] - 35s 576ms/step - loss: 0.0612 - dice_loss: 0.0444 - val_loss: 0.0904 - val_dice_loss: 0.0662
#
# Epoch 00039: LearningRateScheduler reducing learning rate to tf.Tensor(0.0001355157, shape=(), dtype=float32).
# Epoch 39/50
# 60/60 [==============================] - 35s 575ms/step - loss: 0.0609 - dice_loss: 0.0441 - val_loss: 0.0829 - val_dice_loss: 0.0605
#
# Epoch 00040: LearningRateScheduler reducing learning rate to tf.Tensor(0.00011474339, shape=(), dtype=float32).
# Epoch 40/50
# 60/60 [==============================] - 36s 594ms/step - loss: 0.0573 - dice_loss: 0.0418 - val_loss: 0.0788 - val_dice_loss: 0.0576
#
# Epoch 00041: LearningRateScheduler reducing learning rate to tf.Tensor(9.54915e-05, shape=(), dtype=float32).
# Epoch 41/50
# 60/60 [==============================] - 35s 577ms/step - loss: 0.0561 - dice_loss: 0.0407 - val_loss: 0.0792 - val_dice_loss: 0.0577
#
# Epoch 00042: LearningRateScheduler reducing learning rate to tf.Tensor(7.783601e-05, shape=(), dtype=float32).
# Epoch 42/50
# 60/60 [==============================] - 36s 593ms/step - loss: 0.0561 - dice_loss: 0.0405 - val_loss: 0.0768 - val_dice_loss: 0.0559
#
# Epoch 00043: LearningRateScheduler reducing learning rate to tf.Tensor(6.184671e-05, shape=(), dtype=float32).
# Epoch 43/50
# 60/60 [==============================] - 36s 596ms/step - loss: 0.0529 - dice_loss: 0.0382 - val_loss: 0.0738 - val_dice_loss: 0.0536
#
# Epoch 00044: LearningRateScheduler reducing learning rate to tf.Tensor(4.7586444e-05, shape=(), dtype=float32).
# Epoch 44/50
# 60/60 [==============================] - 35s 576ms/step - loss: 0.0543 - dice_loss: 0.0395 - val_loss: 0.0744 - val_dice_loss: 0.0541
#
# Epoch 00045: LearningRateScheduler reducing learning rate to tf.Tensor(3.5111727e-05, shape=(), dtype=float32).
# Epoch 45/50
# 60/60 [==============================] - 36s 597ms/step - loss: 0.0526 - dice_loss: 0.0380 - val_loss: 0.0727 - val_dice_loss: 0.0529
#
# Epoch 00046: LearningRateScheduler reducing learning rate to tf.Tensor(2.4471761e-05, shape=(), dtype=float32).
# Epoch 46/50
# 60/60 [==============================] - 36s 596ms/step - loss: 0.0520 - dice_loss: 0.0376 - val_loss: 0.0723 - val_dice_loss: 0.0526
#
# Epoch 00047: LearningRateScheduler reducing learning rate to tf.Tensor(1.5708387e-05, shape=(), dtype=float32).
# Epoch 47/50
# 60/60 [==============================] - 36s 595ms/step - loss: 0.0507 - dice_loss: 0.0368 - val_loss: 0.0718 - val_dice_loss: 0.0522
#
# Epoch 00048: LearningRateScheduler reducing learning rate to tf.Tensor(8.856387e-06, shape=(), dtype=float32).
# Epoch 48/50
# 60/60 [==============================] - 36s 596ms/step - loss: 0.0500 - dice_loss: 0.0361 - val_loss: 0.0715 - val_dice_loss: 0.0520
#
# Epoch 00049: LearningRateScheduler reducing learning rate to tf.Tensor(3.9426386e-06, shape=(), dtype=float32).
# Epoch 49/50
# 60/60 [==============================] - 36s 598ms/step - loss: 0.0494 - dice_loss: 0.0357 - val_loss: 0.0713 - val_dice_loss: 0.0518
#
# Epoch 00050: LearningRateScheduler reducing learning rate to tf.Tensor(9.866358e-07, shape=(), dtype=float32).
# Epoch 50/50
# 60/60 [==============================] - 36s 594ms/step - loss: 0.0509 - dice_loss: 0.0368 - val_loss: 0.0712 - val_dice_loss: 0.0518

# %%
# print sample image after training
print_images()

# %% [markdown]
# ### Plot the loss
#
# 저장된 학습 진행과정(history)을 시각화

# %%
dice_loss = history.history['dice_loss']
loss = history.history['loss']
val_dice_loss = history.history['val_dice_loss']
val_loss = history.history['val_loss']

epochs_range = range(max_epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, loss, label='Loss')
plt.plot(epochs_range, dice_loss, label='Dice Loss')
plt.legend(loc='upper right')
plt.title('Train Loss')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, val_loss, label='Val Loss')
plt.plot(epochs_range, val_dice_loss, label='Val Dice Loss')
plt.legend(loc='upper right')
plt.title('Valid Loss')
plt.show()

# %% [markdown]
# ### Restore the latest checkpoint
#
#  - 저장된 모델의 가중치를 불러오기

# %%
# restoring the latest checkpoint in checkpoint_dir
model.load_weights(checkpoint_dir)

# %% [markdown]
# ### Evaluate the test dataset
#
# 불러온 가중치를 이용해서 모델을 평가

# %% [markdown]
#  * 테스트 데이터셋을 불러와서 meanIoU 값을 구해보기

# %%
mean = []

for images, labels in test_dataset:
    predictions = model(images, training=False)
    m = mean_iou(labels, predictions)
    mean.append(m)

mean = np.array(mean)
mean = np.mean(mean)
print("mean_iou: {}".format(mean))
# Out:
# mean_iou: 0.9324408891959867

# %% [markdown]
#  * Test Dataset 내에 데이터들을 얼만큼 잘 맞추었는지 직접 확인

# %%
## Define print function
def print_images():
    for test_images, test_labels in test_dataset.take(1):
        predictions = model(test_images, training=False)

        for i in range(batch_size):
            plt.figure(figsize=(10, 20))
            plt.subplot(1, 3, 1)
            plt.imshow(test_images[i,: , :, :])
            plt.title("Input image")

            plt.subplot(1, 3, 2)
            plt.imshow(test_labels[i, :, :, 0])
            plt.title("Actual Mask")

            plt.subplot(1, 3, 3)
            plt.imshow(predictions[i, :, :, 0])
            plt.title("Predicted Mask")
            plt.show()

# %%
print_images()

# %% [markdown]
# ## Pretrained U-Net(VGG-16) 모델 학습 및 평가

# %%
class Vgg16UNet(tf.keras.Model):
    def __init__(self):
        super(Vgg16UNet, self).__init__()
        self.vgg16 = tf.keras.applications.VGG16(input_shape=img_shape,
                                         include_top=False,
                                         weights='imagenet')
        layer_outputs = [layer.output for layer in self.vgg16.layers]
        self.vgg16_act = models.Model(inputs=self.vgg16.input, 
                                      outputs=[layer_outputs[2], 
                                               layer_outputs[5], 
                                               layer_outputs[9], 
                                               layer_outputs[13], 
                                               layer_outputs[17]])


        self.center = ConvBlock(1024)

        self.decoder_block4 = DecoderBlock(512)
        self.decoder_block3 = DecoderBlock(256)
        self.decoder_block2 = DecoderBlock(128)
        self.decoder_block1 = DecoderBlock(64)

        self.output_conv = layers.Conv2D(1, 1, activation='sigmoid')

    def call(self, inputs, training=True):

        encoder1, encoder2, encoder3, encoder4, center = self.vgg16_act(inputs) 

        decoder4 = self.decoder_block4(center, encoder4)
        decoder3 = self.decoder_block3(decoder4, encoder3)
        decoder2 = self.decoder_block2(decoder3, encoder2)
        decoder1 = self.decoder_block1(decoder2, encoder1)
        
        outputs = self.output_conv(decoder1)

        return outputs

# %%
pretrained_unet_model = Vgg16UNet()

# %%
def dice_coeff(y_true, y_pred):
    smooth = 1e-10
    # Flatten
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    score = (2. * intersection + smooth) / (tf.reduce_sum(tf.square(y_true_f)) + \
                                            tf.reduce_sum(tf.square(y_pred_f)) + smooth)

    return score

# %%
def dice_loss(y_true, y_pred):
    loss = 1 - dice_coeff(y_true, y_pred)
    return loss

# %%
def bce_dice_loss(y_true, y_pred):
    loss = tf.reduce_mean(losses.binary_crossentropy(y_true, y_pred)) + \
          dice_loss(y_true, y_pred)
    return loss

# %%
optimizer = tf.keras.optimizers.Adam() # 기본 Learning rate 사용

# %%
print('select the Pretrained U-Net model')
model = pretrained_unet_model
checkpoint_dir =os.path.join(DATASET_PATH,'train_ckpt/pretrained_unet_model')
# Out:
# select the Pretrained U-Net model

# %%
model.compile(optimizer=optimizer, loss=bce_dice_loss, metrics=[dice_loss])
predictions = model(tf.random.normal([batch_size, image_size, image_size, 3]))
print(predictions.shape)
# Out:
# (8, 256, 256, 1)

# %%
model.summary()

# %% [markdown]
# ### Callbacks

# %%
if not os.path.isdir(checkpoint_dir):
    os.makedirs(checkpoint_dir)

cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_dir,
                                                 save_weights_only=True,
                                                 monitor='val_loss',
                                                 mode='auto',
                                                 save_best_only=True,
                                                 verbose=0)

# %%
cos_decay = tf.keras.experimental.CosineDecay(1e-3, 
                                              max_epochs)
lr_callback = tf.keras.callbacks.LearningRateScheduler(cos_decay, verbose=1)

# %%
## Define print function
def print_images():
    for test_images, test_labels in test_dataset.take(1):
        predictions = model(test_images, training=False)

        plt.figure(figsize=(10, 20))
        plt.subplot(1, 3, 1)
        plt.imshow(test_images[0,: , :, :])
        plt.title("Input image")

        plt.subplot(1, 3, 2)
        plt.imshow(test_labels[0, :, :, 0])
        plt.title("Actual Mask")

        plt.subplot(1, 3, 3)
        plt.imshow(predictions[0, :, :, 0])
        plt.title("Predicted Mask")
        plt.show()

# %%
history = model.fit(train_dataset,
                    epochs=max_epochs,    # 50
                    steps_per_epoch=num_train_examples//batch_size,
                    validation_data=test_dataset,
                    validation_steps=num_test_examples//batch_size,
                    callbacks=[cp_callback, lr_callback]
                    )
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to tf.Tensor(0.001, shape=(), dtype=float32).
# Epoch 1/50
#  2/60 [>.............................] - ETA: 10s - loss: 1.5205 - dice_loss: 0.7710WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1418s vs `on_train_batch_end` time: 0.2261s). Check your callbacks.
# 60/60 [==============================] - ETA: 0s - loss: 0.8606 - dice_loss: 0.6117WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0034s vs `on_test_batch_end` time: 0.1144s). Check your callbacks.
# 60/60 [==============================] - 23s 383ms/step - loss: 0.8606 - dice_loss: 0.6117 - val_loss: 1.8701 - val_dice_loss: 0.8367
#
# Epoch 00002: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009990134, shape=(), dtype=float32).
# Epoch 2/50
# 60/60 [==============================] - 23s 378ms/step - loss: 0.6344 - dice_loss: 0.4765 - val_loss: 12.8745 - val_dice_loss: 0.8841
#
# Epoch 00003: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009960574, shape=(), dtype=float32).
# Epoch 3/50
# 60/60 [==============================] - 23s 380ms/step - loss: 0.5430 - dice_loss: 0.4077 - val_loss: 5.1760 - val_dice_loss: 0.8544
#
# Epoch 00004: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009911436, shape=(), dtype=float32).
# Epoch 4/50
# 60/60 [==============================] - 23s 389ms/step - loss: 0.4745 - dice_loss: 0.3549 - val_loss: 0.8876 - val_dice_loss: 0.7104
#
# Epoch 00005: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009842915, shape=(), dtype=float32).
# Epoch 5/50
# 60/60 [==============================] - 23s 382ms/step - loss: 0.4149 - dice_loss: 0.3107 - val_loss: 1.2593 - val_dice_loss: 0.6813
#
# Epoch 00006: LearningRateScheduler reducing learning rate to tf.Tensor(0.00097552827, shape=(), dtype=float32).
# Epoch 6/50
# 60/60 [==============================] - 23s 390ms/step - loss: 0.3837 - dice_loss: 0.2861 - val_loss: 0.6471 - val_dice_loss: 0.4247
#
# Epoch 00007: LearningRateScheduler reducing learning rate to tf.Tensor(0.00096488826, shape=(), dtype=float32).
# Epoch 7/50
# 60/60 [==============================] - 23s 391ms/step - loss: 0.3299 - dice_loss: 0.2436 - val_loss: 0.5531 - val_dice_loss: 0.4280
#
# Epoch 00008: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009524136, shape=(), dtype=float32).
# Epoch 8/50
# 60/60 [==============================] - 23s 391ms/step - loss: 0.3155 - dice_loss: 0.2344 - val_loss: 0.4855 - val_dice_loss: 0.3744
#
# Epoch 00009: LearningRateScheduler reducing learning rate to tf.Tensor(0.00093815336, shape=(), dtype=float32).
# Epoch 9/50
# 60/60 [==============================] - 23s 382ms/step - loss: 0.2697 - dice_loss: 0.1994 - val_loss: 0.6130 - val_dice_loss: 0.4125
#
# Epoch 00010: LearningRateScheduler reducing learning rate to tf.Tensor(0.000922164, shape=(), dtype=float32).
# Epoch 10/50
# 60/60 [==============================] - 23s 391ms/step - loss: 0.2562 - dice_loss: 0.1894 - val_loss: 0.4259 - val_dice_loss: 0.3294
#
# Epoch 00011: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009045085, shape=(), dtype=float32).
# Epoch 11/50
# 60/60 [==============================] - 23s 382ms/step - loss: 0.2638 - dice_loss: 0.1946 - val_loss: 0.4342 - val_dice_loss: 0.3351
#
# Epoch 00012: LearningRateScheduler reducing learning rate to tf.Tensor(0.0008852567, shape=(), dtype=float32).
# Epoch 12/50
# 60/60 [==============================] - 23s 382ms/step - loss: 0.2162 - dice_loss: 0.1589 - val_loss: 0.4964 - val_dice_loss: 0.3844
#
# Epoch 00013: LearningRateScheduler reducing learning rate to tf.Tensor(0.00086448435, shape=(), dtype=float32).
# Epoch 13/50
# 60/60 [==============================] - 23s 390ms/step - loss: 0.2019 - dice_loss: 0.1484 - val_loss: 0.2987 - val_dice_loss: 0.2227
#
# Epoch 00014: LearningRateScheduler reducing learning rate to tf.Tensor(0.00084227364, shape=(), dtype=float32).
# Epoch 14/50
# 60/60 [==============================] - 23s 391ms/step - loss: 0.1790 - dice_loss: 0.1315 - val_loss: 0.2459 - val_dice_loss: 0.1783
#
# Epoch 00015: LearningRateScheduler reducing learning rate to tf.Tensor(0.00081871205, shape=(), dtype=float32).
# Epoch 15/50
# 60/60 [==============================] - 23s 382ms/step - loss: 0.1774 - dice_loss: 0.1302 - val_loss: 0.2623 - val_dice_loss: 0.1958
#
# Epoch 00016: LearningRateScheduler reducing learning rate to tf.Tensor(0.00079389266, shape=(), dtype=float32).
# Epoch 16/50
# 60/60 [==============================] - 23s 391ms/step - loss: 0.1577 - dice_loss: 0.1156 - val_loss: 0.2187 - val_dice_loss: 0.1667
#
# Epoch 00017: LearningRateScheduler reducing learning rate to tf.Tensor(0.00076791336, shape=(), dtype=float32).
# Epoch 17/50
# 60/60 [==============================] - 23s 382ms/step - loss: 0.1405 - dice_loss: 0.1026 - val_loss: 0.2665 - val_dice_loss: 0.1961
#
# Epoch 00018: LearningRateScheduler reducing learning rate to tf.Tensor(0.0007408768, shape=(), dtype=float32).
# Epoch 18/50
# 60/60 [==============================] - 23s 391ms/step - loss: 0.1639 - dice_loss: 0.1209 - val_loss: 0.1350 - val_dice_loss: 0.0973
#
# Epoch 00019: LearningRateScheduler reducing learning rate to tf.Tensor(0.00071288965, shape=(), dtype=float32).
# Epoch 19/50
# 60/60 [==============================] - 23s 383ms/step - loss: 0.1125 - dice_loss: 0.0809 - val_loss: 0.1886 - val_dice_loss: 0.1403
#
# Epoch 00020: LearningRateScheduler reducing learning rate to tf.Tensor(0.00068406225, shape=(), dtype=float32).
# Epoch 20/50
# 60/60 [==============================] - 23s 383ms/step - loss: 0.1186 - dice_loss: 0.0864 - val_loss: 0.2885 - val_dice_loss: 0.2239
#
# Epoch 00021: LearningRateScheduler reducing learning rate to tf.Tensor(0.0006545085, shape=(), dtype=float32).
# Epoch 21/50
# 60/60 [==============================] - 24s 392ms/step - loss: 0.0991 - dice_loss: 0.0712 - val_loss: 0.1019 - val_dice_loss: 0.0748
#
# Epoch 00022: LearningRateScheduler reducing learning rate to tf.Tensor(0.00062434503, shape=(), dtype=float32).
# Epoch 22/50
# 60/60 [==============================] - 23s 384ms/step - loss: 0.0965 - dice_loss: 0.0699 - val_loss: 0.1177 - val_dice_loss: 0.0864
#
# Epoch 00023: LearningRateScheduler reducing learning rate to tf.Tensor(0.00059369067, shape=(), dtype=float32).
# Epoch 23/50
# 60/60 [==============================] - 24s 394ms/step - loss: 0.0879 - dice_loss: 0.0635 - val_loss: 0.1013 - val_dice_loss: 0.0747
#
# Epoch 00024: LearningRateScheduler reducing learning rate to tf.Tensor(0.00056266657, shape=(), dtype=float32).
# Epoch 24/50
# 60/60 [==============================] - 23s 385ms/step - loss: 0.0794 - dice_loss: 0.0574 - val_loss: 0.1091 - val_dice_loss: 0.0804
#
# Epoch 00025: LearningRateScheduler reducing learning rate to tf.Tensor(0.00053139526, shape=(), dtype=float32).
# Epoch 25/50
# 60/60 [==============================] - 23s 385ms/step - loss: 0.0929 - dice_loss: 0.0675 - val_loss: 0.4793 - val_dice_loss: 0.3651
#
# Epoch 00026: LearningRateScheduler reducing learning rate to tf.Tensor(0.00049999997, shape=(), dtype=float32).
# Epoch 26/50
# 60/60 [==============================] - 23s 386ms/step - loss: 0.1255 - dice_loss: 0.0914 - val_loss: 0.1406 - val_dice_loss: 0.1035
#
# Epoch 00027: LearningRateScheduler reducing learning rate to tf.Tensor(0.0004686048, shape=(), dtype=float32).
# Epoch 27/50
# 60/60 [==============================] - 23s 385ms/step - loss: 0.1373 - dice_loss: 0.1010 - val_loss: 0.1787 - val_dice_loss: 0.1306
#
# Epoch 00028: LearningRateScheduler reducing learning rate to tf.Tensor(0.00043733336, shape=(), dtype=float32).
# Epoch 28/50
# 60/60 [==============================] - 23s 386ms/step - loss: 0.0963 - dice_loss: 0.0700 - val_loss: 0.1958 - val_dice_loss: 0.1478
#
# Epoch 00029: LearningRateScheduler reducing learning rate to tf.Tensor(0.00040630935, shape=(), dtype=float32).
# Epoch 29/50
# 60/60 [==============================] - 23s 386ms/step - loss: 0.0775 - dice_loss: 0.0563 - val_loss: 0.1176 - val_dice_loss: 0.0869
#
# Epoch 00030: LearningRateScheduler reducing learning rate to tf.Tensor(0.00037565507, shape=(), dtype=float32).
# Epoch 30/50
# 60/60 [==============================] - 23s 386ms/step - loss: 0.0701 - dice_loss: 0.0506 - val_loss: 0.1487 - val_dice_loss: 0.1110
#
# Epoch 00031: LearningRateScheduler reducing learning rate to tf.Tensor(0.00034549143, shape=(), dtype=float32).
# Epoch 31/50
# 60/60 [==============================] - 24s 395ms/step - loss: 0.0659 - dice_loss: 0.0476 - val_loss: 0.0976 - val_dice_loss: 0.0721
#
# Epoch 00032: LearningRateScheduler reducing learning rate to tf.Tensor(0.0003159377, shape=(), dtype=float32).
# Epoch 32/50
# 60/60 [==============================] - 24s 394ms/step - loss: 0.0699 - dice_loss: 0.0517 - val_loss: 0.0850 - val_dice_loss: 0.0628
#
# Epoch 00033: LearningRateScheduler reducing learning rate to tf.Tensor(0.00028711034, shape=(), dtype=float32).
# Epoch 33/50
# 60/60 [==============================] - 23s 386ms/step - loss: 0.0599 - dice_loss: 0.0432 - val_loss: 0.0911 - val_dice_loss: 0.0675
#
# Epoch 00034: LearningRateScheduler reducing learning rate to tf.Tensor(0.0002591231, shape=(), dtype=float32).
# Epoch 34/50
# 60/60 [==============================] - 24s 395ms/step - loss: 0.0560 - dice_loss: 0.0403 - val_loss: 0.0766 - val_dice_loss: 0.0565
#
# Epoch 00035: LearningRateScheduler reducing learning rate to tf.Tensor(0.00023208655, shape=(), dtype=float32).
# Epoch 35/50
# 60/60 [==============================] - 23s 386ms/step - loss: 0.0546 - dice_loss: 0.0394 - val_loss: 0.0767 - val_dice_loss: 0.0559
#
# Epoch 00036: LearningRateScheduler reducing learning rate to tf.Tensor(0.00020610739, shape=(), dtype=float32).
# Epoch 36/50
# 60/60 [==============================] - 24s 395ms/step - loss: 0.0516 - dice_loss: 0.0372 - val_loss: 0.0725 - val_dice_loss: 0.0528
#
# Epoch 00037: LearningRateScheduler reducing learning rate to tf.Tensor(0.00018128792, shape=(), dtype=float32).
# Epoch 37/50
# 60/60 [==============================] - 23s 386ms/step - loss: 0.0516 - dice_loss: 0.0372 - val_loss: 0.0745 - val_dice_loss: 0.0545
#
# Epoch 00038: LearningRateScheduler reducing learning rate to tf.Tensor(0.00015772645, shape=(), dtype=float32).
# Epoch 38/50
# 60/60 [==============================] - 24s 396ms/step - loss: 0.0491 - dice_loss: 0.0354 - val_loss: 0.0717 - val_dice_loss: 0.0523
#
# Epoch 00039: LearningRateScheduler reducing learning rate to tf.Tensor(0.0001355157, shape=(), dtype=float32).
# Epoch 39/50
# 60/60 [==============================] - 24s 395ms/step - loss: 0.0480 - dice_loss: 0.0346 - val_loss: 0.0714 - val_dice_loss: 0.0521
#
# Epoch 00040: LearningRateScheduler reducing learning rate to tf.Tensor(0.00011474339, shape=(), dtype=float32).
# Epoch 40/50
# 60/60 [==============================] - 24s 396ms/step - loss: 0.0484 - dice_loss: 0.0350 - val_loss: 0.0692 - val_dice_loss: 0.0503
#
# Epoch 00041: LearningRateScheduler reducing learning rate to tf.Tensor(9.54915e-05, shape=(), dtype=float32).
# Epoch 41/50
# 60/60 [==============================] - 24s 396ms/step - loss: 0.0462 - dice_loss: 0.0333 - val_loss: 0.0681 - val_dice_loss: 0.0495
#
# Epoch 00042: LearningRateScheduler reducing learning rate to tf.Tensor(7.783601e-05, shape=(), dtype=float32).
# Epoch 42/50
# 60/60 [==============================] - 24s 395ms/step - loss: 0.0459 - dice_loss: 0.0331 - val_loss: 0.0679 - val_dice_loss: 0.0492
#
# Epoch 00043: LearningRateScheduler reducing learning rate to tf.Tensor(6.184671e-05, shape=(), dtype=float32).
# Epoch 43/50
# 60/60 [==============================] - 23s 387ms/step - loss: 0.0475 - dice_loss: 0.0345 - val_loss: 0.0713 - val_dice_loss: 0.0519
#
# Epoch 00044: LearningRateScheduler reducing learning rate to tf.Tensor(4.7586444e-05, shape=(), dtype=float32).
# Epoch 44/50
# 60/60 [==============================] - 24s 395ms/step - loss: 0.0449 - dice_loss: 0.0322 - val_loss: 0.0676 - val_dice_loss: 0.0490
#
# Epoch 00045: LearningRateScheduler reducing learning rate to tf.Tensor(3.5111727e-05, shape=(), dtype=float32).
# Epoch 45/50
# 60/60 [==============================] - 24s 396ms/step - loss: 0.0451 - dice_loss: 0.0326 - val_loss: 0.0672 - val_dice_loss: 0.0487
#
# Epoch 00046: LearningRateScheduler reducing learning rate to tf.Tensor(2.4471761e-05, shape=(), dtype=float32).
# Epoch 46/50
# 60/60 [==============================] - 23s 387ms/step - loss: 0.0453 - dice_loss: 0.0327 - val_loss: 0.0674 - val_dice_loss: 0.0489
#
# Epoch 00047: LearningRateScheduler reducing learning rate to tf.Tensor(1.5708387e-05, shape=(), dtype=float32).
# Epoch 47/50
# 60/60 [==============================] - 24s 395ms/step - loss: 0.0435 - dice_loss: 0.0312 - val_loss: 0.0670 - val_dice_loss: 0.0486
#
# Epoch 00048: LearningRateScheduler reducing learning rate to tf.Tensor(8.856387e-06, shape=(), dtype=float32).
# Epoch 48/50
# 60/60 [==============================] - 24s 395ms/step - loss: 0.0449 - dice_loss: 0.0324 - val_loss: 0.0668 - val_dice_loss: 0.0485
#
# Epoch 00049: LearningRateScheduler reducing learning rate to tf.Tensor(3.9426386e-06, shape=(), dtype=float32).
# Epoch 49/50
# 60/60 [==============================] - 24s 396ms/step - loss: 0.0449 - dice_loss: 0.0325 - val_loss: 0.0668 - val_dice_loss: 0.0484
#
# Epoch 00050: LearningRateScheduler reducing learning rate to tf.Tensor(9.866358e-07, shape=(), dtype=float32).
# Epoch 50/50
# 60/60 [==============================] - 24s 396ms/step - loss: 0.0447 - dice_loss: 0.0323 - val_loss: 0.0667 - val_dice_loss: 0.0484

# %%
# print sample image after training
print_images()

# %% [markdown]
# ### Plot the loss
#
# 저장된 학습 진행과정(history)을 시각화

# %%
dice_loss = history.history['dice_loss']
loss = history.history['loss']
val_dice_loss = history.history['val_dice_loss']
val_loss = history.history['val_loss']

epochs_range = range(max_epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, loss, label='Loss')
plt.plot(epochs_range, dice_loss, label='Dice Loss')
plt.legend(loc='upper right')
plt.title('Train Loss')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, val_loss, label='Val Loss')
plt.plot(epochs_range, val_dice_loss, label='Val Dice Loss')
plt.legend(loc='upper right')
plt.title('Valid Loss')
plt.show()

# %% [markdown]
# ### Restore the latest checkpoint
#
#  - 저장된 모델의 가중치를 불러오기

# %%
# restoring the latest checkpoint in checkpoint_dir
model.load_weights(checkpoint_dir)

# %% [markdown]
# ### Evaluate the test dataset
#
# 불러온 가중치를 이용해서 모델을 평가

# %% [markdown]
#  * 테스트 데이터셋을 불러와서 meanIoU 값을 구해보기

# %%
mean = []

for images, labels in test_dataset:
    predictions = model(images, training=False)
    m = mean_iou(labels, predictions)
    mean.append(m)

mean = np.array(mean)
mean = np.mean(mean)
print("mean_iou: {}".format(mean))
# Out:
# mean_iou: 0.9363911557821669

# %% [markdown]
#  * Test Dataset 내에 데이터들을 얼만큼 잘 맞추었는지 직접 확인

# %%
## Define print function
def print_images():
    for test_images, test_labels in test_dataset.take(1):
        predictions = model(test_images, training=False)

        for i in range(batch_size):
            plt.figure(figsize=(10, 20))
            plt.subplot(1, 3, 1)
            plt.imshow(test_images[i,: , :, :])
            plt.title("Input image")

            plt.subplot(1, 3, 2)
            plt.imshow(test_labels[i, :, :, 0])
            plt.title("Actual Mask")

            plt.subplot(1, 3, 3)
            plt.imshow(predictions[i, :, :, 0])
            plt.title("Predicted Mask")
            plt.show()

# %%
print_images()
