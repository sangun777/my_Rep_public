# %% [markdown]
# # 2-7. 프로젝트: ResNet Ablation Study

# %% [markdown]
# 1) ResNet 기본 블록 구성하기
#
# - 이제 ResNet-34와 ResNet-50 네트워크를 직접 만든다고 생각해봅시다.
# - 우선 ResNet-34와 ResNet-50에서 사용되는 블록의 공통점을 찾고 차이점을 찾아봅시다.
# - Deep Residual Learning for Image Recognition(paper)
# https://arxiv.org/pdf/1512.03385.pdf

# %% [markdown]
# 공통점
# - ResNet-34와 ResNet-50은 모두 conv block이라고 불리는 블록 구조를 각각 3, 4, 6, 3개씩 반복해서 쌓은 형태라는 공통점을 가지고 있습니다.
#
# 차이점
# - ResNet-34의 경우 Block은 3x3 kernel인 Convolution layer로만 구성되어있지만, ResNet-50은 1x1 Convolution이 앞뒤로 붙어 더 많은 레이어를 한 블록 내에 가지게 됩니다.

# %% [markdown]
# -  ResNet의 블록을 직접 만들어 봅시다!
# - 모델 내의 앞과 뒤에서 반복되지 않을 것 같은 부분은 함수로 구현하지 않아도 됩니다.
# - 우리가 지금 만들어야 하는 것은 블록을 생성하는 함수
# - 이번 단계에서는 가급적 ResNet 논문을 통해서 구현방법에 대한 정보를 얻으시기를 권합니다.
# - 논문만 보고 스스로 구현해 보는 경험을 통해 딥러닝 개발자로서의 내공과 자신감이 다져지게 될 것

# %% [markdown]
# 2) ResNet-34, ResNet-50 Complete Model
# ResNet-34
#
# - VGG와 같이 블록을 만드는 함수를 사용해서 직접 전체 모델을 만들어 봅시다.
# - ResNet-34와 ResNet-50의 차이에 따라 달라지는 구성(configuration)을 함수에 전달해서 같은 생성 함수 build_resnet()를 통해서 ResNet의 여러가지 버전들을 모두 만들어 낼 수 있도록 해야 합니다.

# %%
from tensorflow import keras

# %% [markdown]
# ## ResNet 34 모델 만들기

# %%
def resnet34_blk1(output, cnt):
    output_2 = keras.layers.Activation('relu')(output)
    if cnt == 0:
        output_2 = keras.layers.MaxPooling2D(
            pool_size=(2,2),
            strides=2,
            name=f'stage{cnt+2}_maxpooling')(output_2)
        
        output = keras.layers.Conv2D(
            filters=64*(2**cnt),
            kernel_size=(3, 3),
            activation='relu',
            kernel_initializer='he_normal',
            padding='same',
            name = f'stage{cnt+2}_1_conv2_1')(output_2)
        
    else:
        output = keras.layers.Conv2D(
            filters=64*(2**cnt),
            kernel_size=(3, 3),
            strides = 2,
            activation='relu',
            kernel_initializer='he_normal',
            padding='same',
            name = f'stage{cnt+2}_1_conv2_1')(output_2) 
    
    output = keras.layers.BatchNormalization(name = f'stage{cnt+2}_1_bn1')(output)
    output = keras.layers.Activation('relu')(output)
    output = keras.layers.Conv2D(
        filters=64*(2**cnt),
        kernel_size=(3, 3),
        activation='relu',
        kernel_initializer='he_normal',
        padding='same',
        name = f'stage{cnt+2}_1_conv2_2')(output)
    output = keras.layers.BatchNormalization(name = f'stage{cnt+2}_1_bn2')(output)
    
    if cnt == 0:
        output_2 = keras.layers.Conv2D(
            filters=64*(2**cnt),
            kernel_size=(1, 1),
            activation='relu',
            kernel_initializer='he_normal',
            padding='valid',
            name = f'stage{cnt+2}_short')(output_2)
    else:
        output_2 = keras.layers.Conv2D(
        filters=64*(2**cnt),
        kernel_size=(1, 1),
        strides = 2,
        activation='relu',
        kernel_initializer='he_normal',
        padding='valid',
        name = f'stage{cnt+2}_short')(output_2)
    
    output = keras.layers.Activation('relu')(output)
    output_2 = keras.layers.BatchNormalization(name = f'stage{cnt+2}_1_bn3')(output_2)
    output = keras.layers.Add(name = f'stage{cnt+2}_1_add')([output, output_2])
    return output

# %%
def resnet34_blk2(output, cnt_blk1, cnt_blk2):
    output_2 = keras.layers.Activation('relu')(output)
    output = keras.layers.Conv2D(
        filters=64*(2**cnt_blk1),
        kernel_size=(3, 3),
        activation='relu',
        kernel_initializer='he_normal',
        padding='same',
        name = f'stage{cnt_blk1+2}_{cnt_blk2+2}_conv2_1')(output_2)
    output = keras.layers.BatchNormalization(name = f'stage{cnt_blk1+2}_{cnt_blk2+2}_bn_1')(output)
    output = keras.layers.Activation('relu')(output)
    output = keras.layers.Conv2D(
        filters=64*(2**cnt_blk1),
        kernel_size=(3, 3),
        activation='relu',
        kernel_initializer='he_normal',
        padding='same',
        name = f'stage{cnt_blk1+2}_{cnt_blk2+2}_conv2_2')(output)
    output = keras.layers.BatchNormalization(name = f'stage{cnt_blk1+2}_{cnt_blk2+2}_bn_2')(output)
    output = keras.layers.Activation('relu')(output)
    output = keras.layers.Add(name = f'stage{cnt_blk1+2}_{cnt_blk2+2}_add')([output, output_2])
    return output

# %%
# ResNet-34 생성 함수
def build_resnet34(input_shape=(32,32,3),num_classes=10):
    
    # 입력 레이어
    input_layer = keras.layers.Input(shape=input_shape, name='input_layer')
    output = input_layer
    output = keras.layers.Conv2D(
        filters=64,
        kernel_size=(7, 7),
        strides = 2,
        activation='relu',
        kernel_initializer='he_normal',
        padding='same')(output)
    output = keras.layers.BatchNormalization()(output)
    
    # blk1 수행 후, blk2 수행횟수
    blk2_cnt_list = [2, 3, 5, 2]
    
    # i : blk1 수행 횟수
    for i in range(4):
        output = resnet34_blk1(output, i)
        for j in range(blk2_cnt_list[i]):
            output = resnet34_blk2(output, i, j)

    # Activation
    output = keras.layers.Activation('relu')(output)

    # Average Pooling
    output = keras.layers.AveragePooling2D(pool_size=(1, 1), strides=1)(output)

    # Flatten width*height*channel을 1차원으로 변경
    output = keras.layers.Flatten(name='flatten_6')(output)
    
    output = keras.layers.Dense(num_classes, activation='softmax', name='fc1000')(output)
    # 왜인지 여기서 num_classes를 초기 값 넣어주면 에러남

    model = keras.Model(inputs = input_layer, outputs=output)

    return model

# %%
def build_resnet(input_shape=(32,32,3),num_classes=10, is_50=False):
    
    if is_50 == False:
        return build_resnet34(input_shape, num_classes)
    
    elif is_50 == True:
        return build_resnet50(input_shape, num_classes)

# %%
resnet_34 = build_resnet(input_shape=(32, 32,3), is_50=False)
resnet_34.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_layer (InputLayer)        [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 64)   9472        input_layer[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 64)   256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_329 (Activation)     (None, 16, 16, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# stage2_maxpooling (MaxPooling2D (None, 8, 8, 64)     0           activation_329[0][0]
# __________________________________________________________________________________________________
# stage2_1_conv2_1 (Conv2D)       (None, 8, 8, 64)     36928       stage2_maxpooling[0][0]
# __________________________________________________________________________________________________
# stage2_1_bn1 (BatchNormalizatio (None, 8, 8, 64)     256         stage2_1_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_330 (Activation)     (None, 8, 8, 64)     0           stage2_1_bn1[0][0]
# __________________________________________________________________________________________________
# stage2_1_conv2_2 (Conv2D)       (None, 8, 8, 64)     36928       activation_330[0][0]
# __________________________________________________________________________________________________
# stage2_1_bn2 (BatchNormalizatio (None, 8, 8, 64)     256         stage2_1_conv2_2[0][0]
# __________________________________________________________________________________________________
# stage2_short (Conv2D)           (None, 8, 8, 64)     4160        stage2_maxpooling[0][0]
# __________________________________________________________________________________________________
# activation_331 (Activation)     (None, 8, 8, 64)     0           stage2_1_bn2[0][0]
# __________________________________________________________________________________________________
# stage2_1_bn3 (BatchNormalizatio (None, 8, 8, 64)     256         stage2_short[0][0]
# __________________________________________________________________________________________________
# stage2_1_add (Add)              (None, 8, 8, 64)     0           activation_331[0][0]
#                                                                  stage2_1_bn3[0][0]
# __________________________________________________________________________________________________
# activation_332 (Activation)     (None, 8, 8, 64)     0           stage2_1_add[0][0]
# __________________________________________________________________________________________________
# stage2_2_conv2_1 (Conv2D)       (None, 8, 8, 64)     36928       activation_332[0][0]
# __________________________________________________________________________________________________
# stage2_2_bn_1 (BatchNormalizati (None, 8, 8, 64)     256         stage2_2_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_333 (Activation)     (None, 8, 8, 64)     0           stage2_2_bn_1[0][0]
# __________________________________________________________________________________________________
# stage2_2_conv2_2 (Conv2D)       (None, 8, 8, 64)     36928       activation_333[0][0]
# __________________________________________________________________________________________________
# stage2_2_bn_2 (BatchNormalizati (None, 8, 8, 64)     256         stage2_2_conv2_2[0][0]
# __________________________________________________________________________________________________
# activation_334 (Activation)     (None, 8, 8, 64)     0           stage2_2_bn_2[0][0]
# __________________________________________________________________________________________________
# stage2_2_add (Add)              (None, 8, 8, 64)     0           activation_334[0][0]
#                                                                  activation_332[0][0]
# __________________________________________________________________________________________________
# activation_335 (Activation)     (None, 8, 8, 64)     0           stage2_2_add[0][0]
# __________________________________________________________________________________________________
# stage2_3_conv2_1 (Conv2D)       (None, 8, 8, 64)     36928       activation_335[0][0]
# __________________________________________________________________________________________________
# stage2_3_bn_1 (BatchNormalizati (None, 8, 8, 64)     256         stage2_3_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_336 (Activation)     (None, 8, 8, 64)     0           stage2_3_bn_1[0][0]
# __________________________________________________________________________________________________
# stage2_3_conv2_2 (Conv2D)       (None, 8, 8, 64)     36928       activation_336[0][0]
# __________________________________________________________________________________________________
# stage2_3_bn_2 (BatchNormalizati (None, 8, 8, 64)     256         stage2_3_conv2_2[0][0]
# __________________________________________________________________________________________________
# activation_337 (Activation)     (None, 8, 8, 64)     0           stage2_3_bn_2[0][0]
# __________________________________________________________________________________________________
# stage2_3_add (Add)              (None, 8, 8, 64)     0           activation_337[0][0]
#                                                                  activation_335[0][0]
# __________________________________________________________________________________________________
# activation_338 (Activation)     (None, 8, 8, 64)     0           stage2_3_add[0][0]
# __________________________________________________________________________________________________
# stage3_1_conv2_1 (Conv2D)       (None, 4, 4, 128)    73856       activation_338[0][0]
# __________________________________________________________________________________________________
# stage3_1_bn1 (BatchNormalizatio (None, 4, 4, 128)    512         stage3_1_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_339 (Activation)     (None, 4, 4, 128)    0           stage3_1_bn1[0][0]
# __________________________________________________________________________________________________
# stage3_1_conv2_2 (Conv2D)       (None, 4, 4, 128)    147584      activation_339[0][0]
# __________________________________________________________________________________________________
# stage3_1_bn2 (BatchNormalizatio (None, 4, 4, 128)    512         stage3_1_conv2_2[0][0]
# __________________________________________________________________________________________________
# stage3_short (Conv2D)           (None, 4, 4, 128)    8320        activation_338[0][0]
# __________________________________________________________________________________________________
# activation_340 (Activation)     (None, 4, 4, 128)    0           stage3_1_bn2[0][0]
# __________________________________________________________________________________________________
# stage3_1_bn3 (BatchNormalizatio (None, 4, 4, 128)    512         stage3_short[0][0]
# __________________________________________________________________________________________________
# stage3_1_add (Add)              (None, 4, 4, 128)    0           activation_340[0][0]
#                                                                  stage3_1_bn3[0][0]
# __________________________________________________________________________________________________
# activation_341 (Activation)     (None, 4, 4, 128)    0           stage3_1_add[0][0]
# __________________________________________________________________________________________________
# stage3_2_conv2_1 (Conv2D)       (None, 4, 4, 128)    147584      activation_341[0][0]
# __________________________________________________________________________________________________
# stage3_2_bn_1 (BatchNormalizati (None, 4, 4, 128)    512         stage3_2_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_342 (Activation)     (None, 4, 4, 128)    0           stage3_2_bn_1[0][0]
# __________________________________________________________________________________________________
# stage3_2_conv2_2 (Conv2D)       (None, 4, 4, 128)    147584      activation_342[0][0]
# __________________________________________________________________________________________________
# stage3_2_bn_2 (BatchNormalizati (None, 4, 4, 128)    512         stage3_2_conv2_2[0][0]
# __________________________________________________________________________________________________
# activation_343 (Activation)     (None, 4, 4, 128)    0           stage3_2_bn_2[0][0]
# __________________________________________________________________________________________________
# stage3_2_add (Add)              (None, 4, 4, 128)    0           activation_343[0][0]
#                                                                  activation_341[0][0]
# __________________________________________________________________________________________________
# activation_344 (Activation)     (None, 4, 4, 128)    0           stage3_2_add[0][0]
# __________________________________________________________________________________________________
# stage3_3_conv2_1 (Conv2D)       (None, 4, 4, 128)    147584      activation_344[0][0]
# __________________________________________________________________________________________________
# stage3_3_bn_1 (BatchNormalizati (None, 4, 4, 128)    512         stage3_3_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_345 (Activation)     (None, 4, 4, 128)    0           stage3_3_bn_1[0][0]
# __________________________________________________________________________________________________
# stage3_3_conv2_2 (Conv2D)       (None, 4, 4, 128)    147584      activation_345[0][0]
# __________________________________________________________________________________________________
# stage3_3_bn_2 (BatchNormalizati (None, 4, 4, 128)    512         stage3_3_conv2_2[0][0]
# __________________________________________________________________________________________________
# activation_346 (Activation)     (None, 4, 4, 128)    0           stage3_3_bn_2[0][0]
# __________________________________________________________________________________________________
# stage3_3_add (Add)              (None, 4, 4, 128)    0           activation_346[0][0]
#                                                                  activation_344[0][0]
# __________________________________________________________________________________________________
# activation_347 (Activation)     (None, 4, 4, 128)    0           stage3_3_add[0][0]
# __________________________________________________________________________________________________
# stage3_4_conv2_1 (Conv2D)       (None, 4, 4, 128)    147584      activation_347[0][0]
# __________________________________________________________________________________________________
# stage3_4_bn_1 (BatchNormalizati (None, 4, 4, 128)    512         stage3_4_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_348 (Activation)     (None, 4, 4, 128)    0           stage3_4_bn_1[0][0]
# __________________________________________________________________________________________________
# stage3_4_conv2_2 (Conv2D)       (None, 4, 4, 128)    147584      activation_348[0][0]
# __________________________________________________________________________________________________
# stage3_4_bn_2 (BatchNormalizati (None, 4, 4, 128)    512         stage3_4_conv2_2[0][0]
# __________________________________________________________________________________________________
# activation_349 (Activation)     (None, 4, 4, 128)    0           stage3_4_bn_2[0][0]
# __________________________________________________________________________________________________
# stage3_4_add (Add)              (None, 4, 4, 128)    0           activation_349[0][0]
#                                                                  activation_347[0][0]
# __________________________________________________________________________________________________
# activation_350 (Activation)     (None, 4, 4, 128)    0           stage3_4_add[0][0]
# __________________________________________________________________________________________________
# stage4_1_conv2_1 (Conv2D)       (None, 2, 2, 256)    295168      activation_350[0][0]
# __________________________________________________________________________________________________
# stage4_1_bn1 (BatchNormalizatio (None, 2, 2, 256)    1024        stage4_1_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_351 (Activation)     (None, 2, 2, 256)    0           stage4_1_bn1[0][0]
# __________________________________________________________________________________________________
# stage4_1_conv2_2 (Conv2D)       (None, 2, 2, 256)    590080      activation_351[0][0]
# __________________________________________________________________________________________________
# stage4_1_bn2 (BatchNormalizatio (None, 2, 2, 256)    1024        stage4_1_conv2_2[0][0]
# __________________________________________________________________________________________________
# stage4_short (Conv2D)           (None, 2, 2, 256)    33024       activation_350[0][0]
# __________________________________________________________________________________________________
# activation_352 (Activation)     (None, 2, 2, 256)    0           stage4_1_bn2[0][0]
# __________________________________________________________________________________________________
# stage4_1_bn3 (BatchNormalizatio (None, 2, 2, 256)    1024        stage4_short[0][0]
# __________________________________________________________________________________________________
# stage4_1_add (Add)              (None, 2, 2, 256)    0           activation_352[0][0]
#                                                                  stage4_1_bn3[0][0]
# __________________________________________________________________________________________________
# activation_353 (Activation)     (None, 2, 2, 256)    0           stage4_1_add[0][0]
# __________________________________________________________________________________________________
# stage4_2_conv2_1 (Conv2D)       (None, 2, 2, 256)    590080      activation_353[0][0]
# __________________________________________________________________________________________________
# stage4_2_bn_1 (BatchNormalizati (None, 2, 2, 256)    1024        stage4_2_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_354 (Activation)     (None, 2, 2, 256)    0           stage4_2_bn_1[0][0]
# __________________________________________________________________________________________________
# stage4_2_conv2_2 (Conv2D)       (None, 2, 2, 256)    590080      activation_354[0][0]
# __________________________________________________________________________________________________
# stage4_2_bn_2 (BatchNormalizati (None, 2, 2, 256)    1024        stage4_2_conv2_2[0][0]
# __________________________________________________________________________________________________
# activation_355 (Activation)     (None, 2, 2, 256)    0           stage4_2_bn_2[0][0]
# __________________________________________________________________________________________________
# stage4_2_add (Add)              (None, 2, 2, 256)    0           activation_355[0][0]
#                                                                  activation_353[0][0]
# __________________________________________________________________________________________________
# activation_356 (Activation)     (None, 2, 2, 256)    0           stage4_2_add[0][0]
# __________________________________________________________________________________________________
# stage4_3_conv2_1 (Conv2D)       (None, 2, 2, 256)    590080      activation_356[0][0]
# __________________________________________________________________________________________________
# stage4_3_bn_1 (BatchNormalizati (None, 2, 2, 256)    1024        stage4_3_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_357 (Activation)     (None, 2, 2, 256)    0           stage4_3_bn_1[0][0]
# __________________________________________________________________________________________________
# stage4_3_conv2_2 (Conv2D)       (None, 2, 2, 256)    590080      activation_357[0][0]
# __________________________________________________________________________________________________
# stage4_3_bn_2 (BatchNormalizati (None, 2, 2, 256)    1024        stage4_3_conv2_2[0][0]
# __________________________________________________________________________________________________
# activation_358 (Activation)     (None, 2, 2, 256)    0           stage4_3_bn_2[0][0]
# __________________________________________________________________________________________________
# stage4_3_add (Add)              (None, 2, 2, 256)    0           activation_358[0][0]
#                                                                  activation_356[0][0]
# __________________________________________________________________________________________________
# activation_359 (Activation)     (None, 2, 2, 256)    0           stage4_3_add[0][0]
# __________________________________________________________________________________________________
# stage4_4_conv2_1 (Conv2D)       (None, 2, 2, 256)    590080      activation_359[0][0]
# __________________________________________________________________________________________________
# stage4_4_bn_1 (BatchNormalizati (None, 2, 2, 256)    1024        stage4_4_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_360 (Activation)     (None, 2, 2, 256)    0           stage4_4_bn_1[0][0]
# __________________________________________________________________________________________________
# stage4_4_conv2_2 (Conv2D)       (None, 2, 2, 256)    590080      activation_360[0][0]
# __________________________________________________________________________________________________
# stage4_4_bn_2 (BatchNormalizati (None, 2, 2, 256)    1024        stage4_4_conv2_2[0][0]
# __________________________________________________________________________________________________
# activation_361 (Activation)     (None, 2, 2, 256)    0           stage4_4_bn_2[0][0]
# __________________________________________________________________________________________________
# stage4_4_add (Add)              (None, 2, 2, 256)    0           activation_361[0][0]
#                                                                  activation_359[0][0]
# __________________________________________________________________________________________________
# activation_362 (Activation)     (None, 2, 2, 256)    0           stage4_4_add[0][0]
# __________________________________________________________________________________________________
# stage4_5_conv2_1 (Conv2D)       (None, 2, 2, 256)    590080      activation_362[0][0]
# __________________________________________________________________________________________________
# stage4_5_bn_1 (BatchNormalizati (None, 2, 2, 256)    1024        stage4_5_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_363 (Activation)     (None, 2, 2, 256)    0           stage4_5_bn_1[0][0]
# __________________________________________________________________________________________________
# stage4_5_conv2_2 (Conv2D)       (None, 2, 2, 256)    590080      activation_363[0][0]
# __________________________________________________________________________________________________
# stage4_5_bn_2 (BatchNormalizati (None, 2, 2, 256)    1024        stage4_5_conv2_2[0][0]
# __________________________________________________________________________________________________
# activation_364 (Activation)     (None, 2, 2, 256)    0           stage4_5_bn_2[0][0]
# __________________________________________________________________________________________________
# stage4_5_add (Add)              (None, 2, 2, 256)    0           activation_364[0][0]
#                                                                  activation_362[0][0]
# __________________________________________________________________________________________________
# activation_365 (Activation)     (None, 2, 2, 256)    0           stage4_5_add[0][0]
# __________________________________________________________________________________________________
# stage4_6_conv2_1 (Conv2D)       (None, 2, 2, 256)    590080      activation_365[0][0]
# __________________________________________________________________________________________________
# stage4_6_bn_1 (BatchNormalizati (None, 2, 2, 256)    1024        stage4_6_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_366 (Activation)     (None, 2, 2, 256)    0           stage4_6_bn_1[0][0]
# __________________________________________________________________________________________________
# stage4_6_conv2_2 (Conv2D)       (None, 2, 2, 256)    590080      activation_366[0][0]
# __________________________________________________________________________________________________
# stage4_6_bn_2 (BatchNormalizati (None, 2, 2, 256)    1024        stage4_6_conv2_2[0][0]
# __________________________________________________________________________________________________
# activation_367 (Activation)     (None, 2, 2, 256)    0           stage4_6_bn_2[0][0]
# __________________________________________________________________________________________________
# stage4_6_add (Add)              (None, 2, 2, 256)    0           activation_367[0][0]
#                                                                  activation_365[0][0]
# __________________________________________________________________________________________________
# activation_368 (Activation)     (None, 2, 2, 256)    0           stage4_6_add[0][0]
# __________________________________________________________________________________________________
# stage5_1_conv2_1 (Conv2D)       (None, 1, 1, 512)    1180160     activation_368[0][0]
# __________________________________________________________________________________________________
# stage5_1_bn1 (BatchNormalizatio (None, 1, 1, 512)    2048        stage5_1_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_369 (Activation)     (None, 1, 1, 512)    0           stage5_1_bn1[0][0]
# __________________________________________________________________________________________________
# stage5_1_conv2_2 (Conv2D)       (None, 1, 1, 512)    2359808     activation_369[0][0]
# __________________________________________________________________________________________________
# stage5_1_bn2 (BatchNormalizatio (None, 1, 1, 512)    2048        stage5_1_conv2_2[0][0]
# __________________________________________________________________________________________________
# stage5_short (Conv2D)           (None, 1, 1, 512)    131584      activation_368[0][0]
# __________________________________________________________________________________________________
# activation_370 (Activation)     (None, 1, 1, 512)    0           stage5_1_bn2[0][0]
# __________________________________________________________________________________________________
# stage5_1_bn3 (BatchNormalizatio (None, 1, 1, 512)    2048        stage5_short[0][0]
# __________________________________________________________________________________________________
# stage5_1_add (Add)              (None, 1, 1, 512)    0           activation_370[0][0]
#                                                                  stage5_1_bn3[0][0]
# __________________________________________________________________________________________________
# activation_371 (Activation)     (None, 1, 1, 512)    0           stage5_1_add[0][0]
# __________________________________________________________________________________________________
# stage5_2_conv2_1 (Conv2D)       (None, 1, 1, 512)    2359808     activation_371[0][0]
# __________________________________________________________________________________________________
# stage5_2_bn_1 (BatchNormalizati (None, 1, 1, 512)    2048        stage5_2_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_372 (Activation)     (None, 1, 1, 512)    0           stage5_2_bn_1[0][0]
# __________________________________________________________________________________________________
# stage5_2_conv2_2 (Conv2D)       (None, 1, 1, 512)    2359808     activation_372[0][0]
# __________________________________________________________________________________________________
# stage5_2_bn_2 (BatchNormalizati (None, 1, 1, 512)    2048        stage5_2_conv2_2[0][0]
# __________________________________________________________________________________________________
# activation_373 (Activation)     (None, 1, 1, 512)    0           stage5_2_bn_2[0][0]
# __________________________________________________________________________________________________
# stage5_2_add (Add)              (None, 1, 1, 512)    0           activation_373[0][0]
#                                                                  activation_371[0][0]
# __________________________________________________________________________________________________
# activation_374 (Activation)     (None, 1, 1, 512)    0           stage5_2_add[0][0]
# __________________________________________________________________________________________________
# stage5_3_conv2_1 (Conv2D)       (None, 1, 1, 512)    2359808     activation_374[0][0]
# __________________________________________________________________________________________________
# stage5_3_bn_1 (BatchNormalizati (None, 1, 1, 512)    2048        stage5_3_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_375 (Activation)     (None, 1, 1, 512)    0           stage5_3_bn_1[0][0]
# __________________________________________________________________________________________________
# stage5_3_conv2_2 (Conv2D)       (None, 1, 1, 512)    2359808     activation_375[0][0]
# __________________________________________________________________________________________________
# stage5_3_bn_2 (BatchNormalizati (None, 1, 1, 512)    2048        stage5_3_conv2_2[0][0]
# __________________________________________________________________________________________________
# activation_376 (Activation)     (None, 1, 1, 512)    0           stage5_3_bn_2[0][0]
# __________________________________________________________________________________________________
# stage5_3_add (Add)              (None, 1, 1, 512)    0           activation_376[0][0]
#                                                                  activation_374[0][0]
# __________________________________________________________________________________________________
# activation_377 (Activation)     (None, 1, 1, 512)    0           stage5_3_add[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 1, 1, 512)    0           activation_377[0][0]
# __________________________________________________________________________________________________
# flatten_6 (Flatten)             (None, 512)          0           average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# fc1000 (Dense)                  (None, 10)           5130        flatten_6[0][0]
# ==================================================================================================
# Total params: 21,319,754
# Trainable params: 21,302,602
# Non-trainable params: 17,152
# __________________________________________________________________________________________________

# %% [markdown]
# ## ResNet 50 모델 만들기

# %%
def resnet50_blk1(output, cnt):
    output_2 = keras.layers.Activation('relu')(output)
    if cnt == 0:
        output_2 = keras.layers.MaxPooling2D(
            pool_size=(2,2),
            strides=2,
            name=f'stage{cnt+2}_maxpooling')(output_2)
        
        output = keras.layers.Conv2D(
            filters=64*(2**cnt),
            kernel_size=(1, 1),
            activation='relu',
            kernel_initializer='he_normal',
            padding='same',
            name = f'stage{cnt+2}_1_conv2_1')(output_2)
        
    else:
        output = keras.layers.Conv2D(
            filters=64*(2**cnt),
            kernel_size=(1, 1),
            strides = 2,
            activation='relu',
            kernel_initializer='he_normal',
            padding='same',
            name = f'stage{cnt+2}_1_conv2_1')(output_2) 
    
    output = keras.layers.BatchNormalization(name = f'stage{cnt+2}_1_bn1')(output)
    output = keras.layers.Activation('relu')(output)
    output = keras.layers.Conv2D(
        filters=64*(2**cnt),
        kernel_size=(3, 3),
        activation='relu',
        kernel_initializer='he_normal',
        padding='same',
        name = f'stage{cnt+2}_1_conv2_2')(output)
    output = keras.layers.BatchNormalization(name = f'stage{cnt+2}_1_bn2')(output)
    output = keras.layers.Activation('relu')(output)
    output = keras.layers.Conv2D(
            filters=64*(2**cnt)*4,
            kernel_size=(1, 1),
            activation='relu',
            kernel_initializer='he_normal',
            padding='same',
            name = f'stage{cnt+2}_1_conv2_3')(output)
    output = keras.layers.BatchNormalization(name = f'stage{cnt+2}_1_bn3')(output)
    
    if cnt == 0:
        output_2 = keras.layers.Conv2D(
            filters=64*(2**cnt)*4,
            kernel_size=(1, 1),
            activation='relu',
            kernel_initializer='he_normal',
            padding='valid',
            name = f'stage{cnt+2}_short')(output_2)
    else:
        output_2 = keras.layers.Conv2D(
        filters=64*(2**cnt)*4,
        kernel_size=(1, 1),
        strides = 2,
        activation='relu',
        kernel_initializer='he_normal',
        padding='valid',
        name = f'stage{cnt+2}_short')(output_2)
    
    output = keras.layers.Activation('relu')(output)
    output_2 = keras.layers.BatchNormalization(name = f'stage{cnt+2}_1_bn4')(output_2)
    output = keras.layers.Add(name = f'stage{cnt+2}_1_add')([output, output_2])
    return output

# %%
def resnet50_blk2(output, cnt_blk1, cnt_blk2):
    output_2 = keras.layers.Activation('relu')(output)
    output = keras.layers.Conv2D(
        filters=64*(2**cnt_blk1),
        kernel_size=(1, 1),
        activation='relu',
        kernel_initializer='he_normal',
        padding='same',
        name = f'stage{cnt_blk1+2}_{cnt_blk2+2}_conv2_1')(output_2)
    output = keras.layers.BatchNormalization(name = f'stage{cnt_blk1+2}_{cnt_blk2+2}_bn_1')(output)
    output = keras.layers.Activation('relu')(output)
    output = keras.layers.Conv2D(
        filters=64*(2**cnt_blk1),
        kernel_size=(3, 3),
        activation='relu',
        kernel_initializer='he_normal',
        padding='same',
        name = f'stage{cnt_blk1+2}_{cnt_blk2+2}_conv2_2')(output)
    output = keras.layers.BatchNormalization(name = f'stage{cnt_blk1+2}_{cnt_blk2+2}_bn_2')(output)
    output = keras.layers.Activation('relu')(output)
    output = keras.layers.Conv2D(
        filters=64*(2**cnt_blk1)*4,
        kernel_size=(1, 1),
        activation='relu',
        kernel_initializer='he_normal',
        padding='same',
        name = f'stage{cnt_blk1+2}_{cnt_blk2+2}_conv2_3')(output)
    output = keras.layers.BatchNormalization(name = f'stage{cnt_blk1+2}_{cnt_blk2+2}_bn_3')(output)
    output = keras.layers.Activation('relu')(output)
    output = keras.layers.Add(name = f'stage{cnt_blk1+2}_{cnt_blk2+2}_add')([output, output_2])
    return output

# %%
# ResNet-50 생성 함수
def build_resnet50(input_shape=(32,32,3),num_classes=10):
    
    # 입력 레이어
    input_layer = keras.layers.Input(shape=input_shape, name='input_layer')
    output = input_layer
    output = keras.layers.Conv2D(
        filters=64,
        kernel_size=(7, 7),
        strides = 2,
        activation='relu',
        kernel_initializer='he_normal',
        padding='same')(output)
    output = keras.layers.BatchNormalization()(output)
    
    # blk1 수행 후, blk2 수행횟수
    blk2_cnt_list = [2, 3, 5, 2]
    
    # i : blk1 수행 횟수
    for i in range(4):
        output = resnet50_blk1(output, i)
        for j in range(blk2_cnt_list[i]):
            output = resnet50_blk2(output, i, j)

    # Activation
    output = keras.layers.Activation('relu')(output)

    # Average Pooling
    output = keras.layers.AveragePooling2D(pool_size=(1, 1), strides=1)(output)

    # Flatten width*height*channel을 1차원으로 변경
    output = keras.layers.Flatten(name='flatten_6')(output)
    
    output = keras.layers.Dense(num_classes, activation='softmax', name='fc1000')(output)
    # 왜인지 여기서 num_classes를 초기 값 넣어주면 에러남

    model = keras.Model(inputs = input_layer, outputs=output)
    return model

# %%
resnet_50 = build_resnet(input_shape=(32, 32,3), is_50=True)
resnet_50.summary()
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_layer (InputLayer)        [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 64)   9472        input_layer[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 64)   256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_378 (Activation)     (None, 16, 16, 64)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# stage2_maxpooling (MaxPooling2D (None, 8, 8, 64)     0           activation_378[0][0]
# __________________________________________________________________________________________________
# stage2_1_conv2_1 (Conv2D)       (None, 8, 8, 64)     4160        stage2_maxpooling[0][0]
# __________________________________________________________________________________________________
# stage2_1_bn1 (BatchNormalizatio (None, 8, 8, 64)     256         stage2_1_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_379 (Activation)     (None, 8, 8, 64)     0           stage2_1_bn1[0][0]
# __________________________________________________________________________________________________
# stage2_1_conv2_2 (Conv2D)       (None, 8, 8, 64)     36928       activation_379[0][0]
# __________________________________________________________________________________________________
# stage2_1_bn2 (BatchNormalizatio (None, 8, 8, 64)     256         stage2_1_conv2_2[0][0]
# __________________________________________________________________________________________________
# activation_380 (Activation)     (None, 8, 8, 64)     0           stage2_1_bn2[0][0]
# __________________________________________________________________________________________________
# stage2_1_conv2_3 (Conv2D)       (None, 8, 8, 256)    16640       activation_380[0][0]
# __________________________________________________________________________________________________
# stage2_1_bn3 (BatchNormalizatio (None, 8, 8, 256)    1024        stage2_1_conv2_3[0][0]
# __________________________________________________________________________________________________
# stage2_short (Conv2D)           (None, 8, 8, 256)    16640       stage2_maxpooling[0][0]
# __________________________________________________________________________________________________
# activation_381 (Activation)     (None, 8, 8, 256)    0           stage2_1_bn3[0][0]
# __________________________________________________________________________________________________
# stage2_1_bn4 (BatchNormalizatio (None, 8, 8, 256)    1024        stage2_short[0][0]
# __________________________________________________________________________________________________
# stage2_1_add (Add)              (None, 8, 8, 256)    0           activation_381[0][0]
#                                                                  stage2_1_bn4[0][0]
# __________________________________________________________________________________________________
# activation_382 (Activation)     (None, 8, 8, 256)    0           stage2_1_add[0][0]
# __________________________________________________________________________________________________
# stage2_2_conv2_1 (Conv2D)       (None, 8, 8, 64)     16448       activation_382[0][0]
# __________________________________________________________________________________________________
# stage2_2_bn_1 (BatchNormalizati (None, 8, 8, 64)     256         stage2_2_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_383 (Activation)     (None, 8, 8, 64)     0           stage2_2_bn_1[0][0]
# __________________________________________________________________________________________________
# stage2_2_conv2_2 (Conv2D)       (None, 8, 8, 64)     36928       activation_383[0][0]
# __________________________________________________________________________________________________
# stage2_2_bn_2 (BatchNormalizati (None, 8, 8, 64)     256         stage2_2_conv2_2[0][0]
# __________________________________________________________________________________________________
# activation_384 (Activation)     (None, 8, 8, 64)     0           stage2_2_bn_2[0][0]
# __________________________________________________________________________________________________
# stage2_2_conv2_3 (Conv2D)       (None, 8, 8, 256)    16640       activation_384[0][0]
# __________________________________________________________________________________________________
# stage2_2_bn_3 (BatchNormalizati (None, 8, 8, 256)    1024        stage2_2_conv2_3[0][0]
# __________________________________________________________________________________________________
# activation_385 (Activation)     (None, 8, 8, 256)    0           stage2_2_bn_3[0][0]
# __________________________________________________________________________________________________
# stage2_2_add (Add)              (None, 8, 8, 256)    0           activation_385[0][0]
#                                                                  activation_382[0][0]
# __________________________________________________________________________________________________
# activation_386 (Activation)     (None, 8, 8, 256)    0           stage2_2_add[0][0]
# __________________________________________________________________________________________________
# stage2_3_conv2_1 (Conv2D)       (None, 8, 8, 64)     16448       activation_386[0][0]
# __________________________________________________________________________________________________
# stage2_3_bn_1 (BatchNormalizati (None, 8, 8, 64)     256         stage2_3_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_387 (Activation)     (None, 8, 8, 64)     0           stage2_3_bn_1[0][0]
# __________________________________________________________________________________________________
# stage2_3_conv2_2 (Conv2D)       (None, 8, 8, 64)     36928       activation_387[0][0]
# __________________________________________________________________________________________________
# stage2_3_bn_2 (BatchNormalizati (None, 8, 8, 64)     256         stage2_3_conv2_2[0][0]
# __________________________________________________________________________________________________
# activation_388 (Activation)     (None, 8, 8, 64)     0           stage2_3_bn_2[0][0]
# __________________________________________________________________________________________________
# stage2_3_conv2_3 (Conv2D)       (None, 8, 8, 256)    16640       activation_388[0][0]
# __________________________________________________________________________________________________
# stage2_3_bn_3 (BatchNormalizati (None, 8, 8, 256)    1024        stage2_3_conv2_3[0][0]
# __________________________________________________________________________________________________
# activation_389 (Activation)     (None, 8, 8, 256)    0           stage2_3_bn_3[0][0]
# __________________________________________________________________________________________________
# stage2_3_add (Add)              (None, 8, 8, 256)    0           activation_389[0][0]
#                                                                  activation_386[0][0]
# __________________________________________________________________________________________________
# activation_390 (Activation)     (None, 8, 8, 256)    0           stage2_3_add[0][0]
# __________________________________________________________________________________________________
# stage3_1_conv2_1 (Conv2D)       (None, 4, 4, 128)    32896       activation_390[0][0]
# __________________________________________________________________________________________________
# stage3_1_bn1 (BatchNormalizatio (None, 4, 4, 128)    512         stage3_1_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_391 (Activation)     (None, 4, 4, 128)    0           stage3_1_bn1[0][0]
# __________________________________________________________________________________________________
# stage3_1_conv2_2 (Conv2D)       (None, 4, 4, 128)    147584      activation_391[0][0]
# __________________________________________________________________________________________________
# stage3_1_bn2 (BatchNormalizatio (None, 4, 4, 128)    512         stage3_1_conv2_2[0][0]
# __________________________________________________________________________________________________
# activation_392 (Activation)     (None, 4, 4, 128)    0           stage3_1_bn2[0][0]
# __________________________________________________________________________________________________
# stage3_1_conv2_3 (Conv2D)       (None, 4, 4, 512)    66048       activation_392[0][0]
# __________________________________________________________________________________________________
# stage3_1_bn3 (BatchNormalizatio (None, 4, 4, 512)    2048        stage3_1_conv2_3[0][0]
# __________________________________________________________________________________________________
# stage3_short (Conv2D)           (None, 4, 4, 512)    131584      activation_390[0][0]
# __________________________________________________________________________________________________
# activation_393 (Activation)     (None, 4, 4, 512)    0           stage3_1_bn3[0][0]
# __________________________________________________________________________________________________
# stage3_1_bn4 (BatchNormalizatio (None, 4, 4, 512)    2048        stage3_short[0][0]
# __________________________________________________________________________________________________
# stage3_1_add (Add)              (None, 4, 4, 512)    0           activation_393[0][0]
#                                                                  stage3_1_bn4[0][0]
# __________________________________________________________________________________________________
# activation_394 (Activation)     (None, 4, 4, 512)    0           stage3_1_add[0][0]
# __________________________________________________________________________________________________
# stage3_2_conv2_1 (Conv2D)       (None, 4, 4, 128)    65664       activation_394[0][0]
# __________________________________________________________________________________________________
# stage3_2_bn_1 (BatchNormalizati (None, 4, 4, 128)    512         stage3_2_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_395 (Activation)     (None, 4, 4, 128)    0           stage3_2_bn_1[0][0]
# __________________________________________________________________________________________________
# stage3_2_conv2_2 (Conv2D)       (None, 4, 4, 128)    147584      activation_395[0][0]
# __________________________________________________________________________________________________
# stage3_2_bn_2 (BatchNormalizati (None, 4, 4, 128)    512         stage3_2_conv2_2[0][0]
# __________________________________________________________________________________________________
# activation_396 (Activation)     (None, 4, 4, 128)    0           stage3_2_bn_2[0][0]
# __________________________________________________________________________________________________
# stage3_2_conv2_3 (Conv2D)       (None, 4, 4, 512)    66048       activation_396[0][0]
# __________________________________________________________________________________________________
# stage3_2_bn_3 (BatchNormalizati (None, 4, 4, 512)    2048        stage3_2_conv2_3[0][0]
# __________________________________________________________________________________________________
# activation_397 (Activation)     (None, 4, 4, 512)    0           stage3_2_bn_3[0][0]
# __________________________________________________________________________________________________
# stage3_2_add (Add)              (None, 4, 4, 512)    0           activation_397[0][0]
#                                                                  activation_394[0][0]
# __________________________________________________________________________________________________
# activation_398 (Activation)     (None, 4, 4, 512)    0           stage3_2_add[0][0]
# __________________________________________________________________________________________________
# stage3_3_conv2_1 (Conv2D)       (None, 4, 4, 128)    65664       activation_398[0][0]
# __________________________________________________________________________________________________
# stage3_3_bn_1 (BatchNormalizati (None, 4, 4, 128)    512         stage3_3_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_399 (Activation)     (None, 4, 4, 128)    0           stage3_3_bn_1[0][0]
# __________________________________________________________________________________________________
# stage3_3_conv2_2 (Conv2D)       (None, 4, 4, 128)    147584      activation_399[0][0]
# __________________________________________________________________________________________________
# stage3_3_bn_2 (BatchNormalizati (None, 4, 4, 128)    512         stage3_3_conv2_2[0][0]
# __________________________________________________________________________________________________
# activation_400 (Activation)     (None, 4, 4, 128)    0           stage3_3_bn_2[0][0]
# __________________________________________________________________________________________________
# stage3_3_conv2_3 (Conv2D)       (None, 4, 4, 512)    66048       activation_400[0][0]
# __________________________________________________________________________________________________
# stage3_3_bn_3 (BatchNormalizati (None, 4, 4, 512)    2048        stage3_3_conv2_3[0][0]
# __________________________________________________________________________________________________
# activation_401 (Activation)     (None, 4, 4, 512)    0           stage3_3_bn_3[0][0]
# __________________________________________________________________________________________________
# stage3_3_add (Add)              (None, 4, 4, 512)    0           activation_401[0][0]
#                                                                  activation_398[0][0]
# __________________________________________________________________________________________________
# activation_402 (Activation)     (None, 4, 4, 512)    0           stage3_3_add[0][0]
# __________________________________________________________________________________________________
# stage3_4_conv2_1 (Conv2D)       (None, 4, 4, 128)    65664       activation_402[0][0]
# __________________________________________________________________________________________________
# stage3_4_bn_1 (BatchNormalizati (None, 4, 4, 128)    512         stage3_4_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_403 (Activation)     (None, 4, 4, 128)    0           stage3_4_bn_1[0][0]
# __________________________________________________________________________________________________
# stage3_4_conv2_2 (Conv2D)       (None, 4, 4, 128)    147584      activation_403[0][0]
# __________________________________________________________________________________________________
# stage3_4_bn_2 (BatchNormalizati (None, 4, 4, 128)    512         stage3_4_conv2_2[0][0]
# __________________________________________________________________________________________________
# activation_404 (Activation)     (None, 4, 4, 128)    0           stage3_4_bn_2[0][0]
# __________________________________________________________________________________________________
# stage3_4_conv2_3 (Conv2D)       (None, 4, 4, 512)    66048       activation_404[0][0]
# __________________________________________________________________________________________________
# stage3_4_bn_3 (BatchNormalizati (None, 4, 4, 512)    2048        stage3_4_conv2_3[0][0]
# __________________________________________________________________________________________________
# activation_405 (Activation)     (None, 4, 4, 512)    0           stage3_4_bn_3[0][0]
# __________________________________________________________________________________________________
# stage3_4_add (Add)              (None, 4, 4, 512)    0           activation_405[0][0]
#                                                                  activation_402[0][0]
# __________________________________________________________________________________________________
# activation_406 (Activation)     (None, 4, 4, 512)    0           stage3_4_add[0][0]
# __________________________________________________________________________________________________
# stage4_1_conv2_1 (Conv2D)       (None, 2, 2, 256)    131328      activation_406[0][0]
# __________________________________________________________________________________________________
# stage4_1_bn1 (BatchNormalizatio (None, 2, 2, 256)    1024        stage4_1_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_407 (Activation)     (None, 2, 2, 256)    0           stage4_1_bn1[0][0]
# __________________________________________________________________________________________________
# stage4_1_conv2_2 (Conv2D)       (None, 2, 2, 256)    590080      activation_407[0][0]
# __________________________________________________________________________________________________
# stage4_1_bn2 (BatchNormalizatio (None, 2, 2, 256)    1024        stage4_1_conv2_2[0][0]
# __________________________________________________________________________________________________
# activation_408 (Activation)     (None, 2, 2, 256)    0           stage4_1_bn2[0][0]
# __________________________________________________________________________________________________
# stage4_1_conv2_3 (Conv2D)       (None, 2, 2, 1024)   263168      activation_408[0][0]
# __________________________________________________________________________________________________
# stage4_1_bn3 (BatchNormalizatio (None, 2, 2, 1024)   4096        stage4_1_conv2_3[0][0]
# __________________________________________________________________________________________________
# stage4_short (Conv2D)           (None, 2, 2, 1024)   525312      activation_406[0][0]
# __________________________________________________________________________________________________
# activation_409 (Activation)     (None, 2, 2, 1024)   0           stage4_1_bn3[0][0]
# __________________________________________________________________________________________________
# stage4_1_bn4 (BatchNormalizatio (None, 2, 2, 1024)   4096        stage4_short[0][0]
# __________________________________________________________________________________________________
# stage4_1_add (Add)              (None, 2, 2, 1024)   0           activation_409[0][0]
#                                                                  stage4_1_bn4[0][0]
# __________________________________________________________________________________________________
# activation_410 (Activation)     (None, 2, 2, 1024)   0           stage4_1_add[0][0]
# __________________________________________________________________________________________________
# stage4_2_conv2_1 (Conv2D)       (None, 2, 2, 256)    262400      activation_410[0][0]
# __________________________________________________________________________________________________
# stage4_2_bn_1 (BatchNormalizati (None, 2, 2, 256)    1024        stage4_2_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_411 (Activation)     (None, 2, 2, 256)    0           stage4_2_bn_1[0][0]
# __________________________________________________________________________________________________
# stage4_2_conv2_2 (Conv2D)       (None, 2, 2, 256)    590080      activation_411[0][0]
# __________________________________________________________________________________________________
# stage4_2_bn_2 (BatchNormalizati (None, 2, 2, 256)    1024        stage4_2_conv2_2[0][0]
# __________________________________________________________________________________________________
# activation_412 (Activation)     (None, 2, 2, 256)    0           stage4_2_bn_2[0][0]
# __________________________________________________________________________________________________
# stage4_2_conv2_3 (Conv2D)       (None, 2, 2, 1024)   263168      activation_412[0][0]
# __________________________________________________________________________________________________
# stage4_2_bn_3 (BatchNormalizati (None, 2, 2, 1024)   4096        stage4_2_conv2_3[0][0]
# __________________________________________________________________________________________________
# activation_413 (Activation)     (None, 2, 2, 1024)   0           stage4_2_bn_3[0][0]
# __________________________________________________________________________________________________
# stage4_2_add (Add)              (None, 2, 2, 1024)   0           activation_413[0][0]
#                                                                  activation_410[0][0]
# __________________________________________________________________________________________________
# activation_414 (Activation)     (None, 2, 2, 1024)   0           stage4_2_add[0][0]
# __________________________________________________________________________________________________
# stage4_3_conv2_1 (Conv2D)       (None, 2, 2, 256)    262400      activation_414[0][0]
# __________________________________________________________________________________________________
# stage4_3_bn_1 (BatchNormalizati (None, 2, 2, 256)    1024        stage4_3_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_415 (Activation)     (None, 2, 2, 256)    0           stage4_3_bn_1[0][0]
# __________________________________________________________________________________________________
# stage4_3_conv2_2 (Conv2D)       (None, 2, 2, 256)    590080      activation_415[0][0]
# __________________________________________________________________________________________________
# stage4_3_bn_2 (BatchNormalizati (None, 2, 2, 256)    1024        stage4_3_conv2_2[0][0]
# __________________________________________________________________________________________________
# activation_416 (Activation)     (None, 2, 2, 256)    0           stage4_3_bn_2[0][0]
# __________________________________________________________________________________________________
# stage4_3_conv2_3 (Conv2D)       (None, 2, 2, 1024)   263168      activation_416[0][0]
# __________________________________________________________________________________________________
# stage4_3_bn_3 (BatchNormalizati (None, 2, 2, 1024)   4096        stage4_3_conv2_3[0][0]
# __________________________________________________________________________________________________
# activation_417 (Activation)     (None, 2, 2, 1024)   0           stage4_3_bn_3[0][0]
# __________________________________________________________________________________________________
# stage4_3_add (Add)              (None, 2, 2, 1024)   0           activation_417[0][0]
#                                                                  activation_414[0][0]
# __________________________________________________________________________________________________
# activation_418 (Activation)     (None, 2, 2, 1024)   0           stage4_3_add[0][0]
# __________________________________________________________________________________________________
# stage4_4_conv2_1 (Conv2D)       (None, 2, 2, 256)    262400      activation_418[0][0]
# __________________________________________________________________________________________________
# stage4_4_bn_1 (BatchNormalizati (None, 2, 2, 256)    1024        stage4_4_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_419 (Activation)     (None, 2, 2, 256)    0           stage4_4_bn_1[0][0]
# __________________________________________________________________________________________________
# stage4_4_conv2_2 (Conv2D)       (None, 2, 2, 256)    590080      activation_419[0][0]
# __________________________________________________________________________________________________
# stage4_4_bn_2 (BatchNormalizati (None, 2, 2, 256)    1024        stage4_4_conv2_2[0][0]
# __________________________________________________________________________________________________
# activation_420 (Activation)     (None, 2, 2, 256)    0           stage4_4_bn_2[0][0]
# __________________________________________________________________________________________________
# stage4_4_conv2_3 (Conv2D)       (None, 2, 2, 1024)   263168      activation_420[0][0]
# __________________________________________________________________________________________________
# stage4_4_bn_3 (BatchNormalizati (None, 2, 2, 1024)   4096        stage4_4_conv2_3[0][0]
# __________________________________________________________________________________________________
# activation_421 (Activation)     (None, 2, 2, 1024)   0           stage4_4_bn_3[0][0]
# __________________________________________________________________________________________________
# stage4_4_add (Add)              (None, 2, 2, 1024)   0           activation_421[0][0]
#                                                                  activation_418[0][0]
# __________________________________________________________________________________________________
# activation_422 (Activation)     (None, 2, 2, 1024)   0           stage4_4_add[0][0]
# __________________________________________________________________________________________________
# stage4_5_conv2_1 (Conv2D)       (None, 2, 2, 256)    262400      activation_422[0][0]
# __________________________________________________________________________________________________
# stage4_5_bn_1 (BatchNormalizati (None, 2, 2, 256)    1024        stage4_5_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_423 (Activation)     (None, 2, 2, 256)    0           stage4_5_bn_1[0][0]
# __________________________________________________________________________________________________
# stage4_5_conv2_2 (Conv2D)       (None, 2, 2, 256)    590080      activation_423[0][0]
# __________________________________________________________________________________________________
# stage4_5_bn_2 (BatchNormalizati (None, 2, 2, 256)    1024        stage4_5_conv2_2[0][0]
# __________________________________________________________________________________________________
# activation_424 (Activation)     (None, 2, 2, 256)    0           stage4_5_bn_2[0][0]
# __________________________________________________________________________________________________
# stage4_5_conv2_3 (Conv2D)       (None, 2, 2, 1024)   263168      activation_424[0][0]
# __________________________________________________________________________________________________
# stage4_5_bn_3 (BatchNormalizati (None, 2, 2, 1024)   4096        stage4_5_conv2_3[0][0]
# __________________________________________________________________________________________________
# activation_425 (Activation)     (None, 2, 2, 1024)   0           stage4_5_bn_3[0][0]
# __________________________________________________________________________________________________
# stage4_5_add (Add)              (None, 2, 2, 1024)   0           activation_425[0][0]
#                                                                  activation_422[0][0]
# __________________________________________________________________________________________________
# activation_426 (Activation)     (None, 2, 2, 1024)   0           stage4_5_add[0][0]
# __________________________________________________________________________________________________
# stage4_6_conv2_1 (Conv2D)       (None, 2, 2, 256)    262400      activation_426[0][0]
# __________________________________________________________________________________________________
# stage4_6_bn_1 (BatchNormalizati (None, 2, 2, 256)    1024        stage4_6_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_427 (Activation)     (None, 2, 2, 256)    0           stage4_6_bn_1[0][0]
# __________________________________________________________________________________________________
# stage4_6_conv2_2 (Conv2D)       (None, 2, 2, 256)    590080      activation_427[0][0]
# __________________________________________________________________________________________________
# stage4_6_bn_2 (BatchNormalizati (None, 2, 2, 256)    1024        stage4_6_conv2_2[0][0]
# __________________________________________________________________________________________________
# activation_428 (Activation)     (None, 2, 2, 256)    0           stage4_6_bn_2[0][0]
# __________________________________________________________________________________________________
# stage4_6_conv2_3 (Conv2D)       (None, 2, 2, 1024)   263168      activation_428[0][0]
# __________________________________________________________________________________________________
# stage4_6_bn_3 (BatchNormalizati (None, 2, 2, 1024)   4096        stage4_6_conv2_3[0][0]
# __________________________________________________________________________________________________
# activation_429 (Activation)     (None, 2, 2, 1024)   0           stage4_6_bn_3[0][0]
# __________________________________________________________________________________________________
# stage4_6_add (Add)              (None, 2, 2, 1024)   0           activation_429[0][0]
#                                                                  activation_426[0][0]
# __________________________________________________________________________________________________
# activation_430 (Activation)     (None, 2, 2, 1024)   0           stage4_6_add[0][0]
# __________________________________________________________________________________________________
# stage5_1_conv2_1 (Conv2D)       (None, 1, 1, 512)    524800      activation_430[0][0]
# __________________________________________________________________________________________________
# stage5_1_bn1 (BatchNormalizatio (None, 1, 1, 512)    2048        stage5_1_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_431 (Activation)     (None, 1, 1, 512)    0           stage5_1_bn1[0][0]
# __________________________________________________________________________________________________
# stage5_1_conv2_2 (Conv2D)       (None, 1, 1, 512)    2359808     activation_431[0][0]
# __________________________________________________________________________________________________
# stage5_1_bn2 (BatchNormalizatio (None, 1, 1, 512)    2048        stage5_1_conv2_2[0][0]
# __________________________________________________________________________________________________
# activation_432 (Activation)     (None, 1, 1, 512)    0           stage5_1_bn2[0][0]
# __________________________________________________________________________________________________
# stage5_1_conv2_3 (Conv2D)       (None, 1, 1, 2048)   1050624     activation_432[0][0]
# __________________________________________________________________________________________________
# stage5_1_bn3 (BatchNormalizatio (None, 1, 1, 2048)   8192        stage5_1_conv2_3[0][0]
# __________________________________________________________________________________________________
# stage5_short (Conv2D)           (None, 1, 1, 2048)   2099200     activation_430[0][0]
# __________________________________________________________________________________________________
# activation_433 (Activation)     (None, 1, 1, 2048)   0           stage5_1_bn3[0][0]
# __________________________________________________________________________________________________
# stage5_1_bn4 (BatchNormalizatio (None, 1, 1, 2048)   8192        stage5_short[0][0]
# __________________________________________________________________________________________________
# stage5_1_add (Add)              (None, 1, 1, 2048)   0           activation_433[0][0]
#                                                                  stage5_1_bn4[0][0]
# __________________________________________________________________________________________________
# activation_434 (Activation)     (None, 1, 1, 2048)   0           stage5_1_add[0][0]
# __________________________________________________________________________________________________
# stage5_2_conv2_1 (Conv2D)       (None, 1, 1, 512)    1049088     activation_434[0][0]
# __________________________________________________________________________________________________
# stage5_2_bn_1 (BatchNormalizati (None, 1, 1, 512)    2048        stage5_2_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_435 (Activation)     (None, 1, 1, 512)    0           stage5_2_bn_1[0][0]
# __________________________________________________________________________________________________
# stage5_2_conv2_2 (Conv2D)       (None, 1, 1, 512)    2359808     activation_435[0][0]
# __________________________________________________________________________________________________
# stage5_2_bn_2 (BatchNormalizati (None, 1, 1, 512)    2048        stage5_2_conv2_2[0][0]
# __________________________________________________________________________________________________
# activation_436 (Activation)     (None, 1, 1, 512)    0           stage5_2_bn_2[0][0]
# __________________________________________________________________________________________________
# stage5_2_conv2_3 (Conv2D)       (None, 1, 1, 2048)   1050624     activation_436[0][0]
# __________________________________________________________________________________________________
# stage5_2_bn_3 (BatchNormalizati (None, 1, 1, 2048)   8192        stage5_2_conv2_3[0][0]
# __________________________________________________________________________________________________
# activation_437 (Activation)     (None, 1, 1, 2048)   0           stage5_2_bn_3[0][0]
# __________________________________________________________________________________________________
# stage5_2_add (Add)              (None, 1, 1, 2048)   0           activation_437[0][0]
#                                                                  activation_434[0][0]
# __________________________________________________________________________________________________
# activation_438 (Activation)     (None, 1, 1, 2048)   0           stage5_2_add[0][0]
# __________________________________________________________________________________________________
# stage5_3_conv2_1 (Conv2D)       (None, 1, 1, 512)    1049088     activation_438[0][0]
# __________________________________________________________________________________________________
# stage5_3_bn_1 (BatchNormalizati (None, 1, 1, 512)    2048        stage5_3_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_439 (Activation)     (None, 1, 1, 512)    0           stage5_3_bn_1[0][0]
# __________________________________________________________________________________________________
# stage5_3_conv2_2 (Conv2D)       (None, 1, 1, 512)    2359808     activation_439[0][0]
# __________________________________________________________________________________________________
# stage5_3_bn_2 (BatchNormalizati (None, 1, 1, 512)    2048        stage5_3_conv2_2[0][0]
# __________________________________________________________________________________________________
# activation_440 (Activation)     (None, 1, 1, 512)    0           stage5_3_bn_2[0][0]
# __________________________________________________________________________________________________
# stage5_3_conv2_3 (Conv2D)       (None, 1, 1, 2048)   1050624     activation_440[0][0]
# __________________________________________________________________________________________________
# stage5_3_bn_3 (BatchNormalizati (None, 1, 1, 2048)   8192        stage5_3_conv2_3[0][0]
# __________________________________________________________________________________________________
# activation_441 (Activation)     (None, 1, 1, 2048)   0           stage5_3_bn_3[0][0]
# __________________________________________________________________________________________________
# stage5_3_add (Add)              (None, 1, 1, 2048)   0           activation_441[0][0]
#                                                                  activation_438[0][0]
# __________________________________________________________________________________________________
# activation_442 (Activation)     (None, 1, 1, 2048)   0           stage5_3_add[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 1, 1, 2048)   0           activation_442[0][0]
# __________________________________________________________________________________________________
# flatten_6 (Flatten)             (None, 2048)         0           average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# fc1000 (Dense)                  (None, 10)           20490       flatten_6[0][0]
# ==================================================================================================
# Total params: 23,608,202
# Trainable params: 23,555,082
# Non-trainable params: 53,120
# __________________________________________________________________________________________________
