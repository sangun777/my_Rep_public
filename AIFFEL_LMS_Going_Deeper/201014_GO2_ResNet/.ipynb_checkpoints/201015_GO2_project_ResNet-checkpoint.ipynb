# %% [markdown]
# # 2-7. 프로젝트: ResNet Ablation Study

# %% [markdown]
# 1) ResNet 기본 블록 구성하기
#
# - 이제 ResNet-34와 ResNet-50 네트워크를 직접 만든다고 생각해봅시다.
# - 우선 ResNet-34와 ResNet-50에서 사용되는 블록의 공통점을 찾고 차이점을 찾아봅시다.
# - Deep Residual Learning for Image Recognition(paper)
# https://arxiv.org/pdf/1512.03385.pdf

# %% [markdown]
# 공통점
# - ResNet-34와 ResNet-50은 모두 conv block이라고 불리는 블록 구조를 각각 3, 4, 6, 3개씩 반복해서 쌓은 형태라는 공통점을 가지고 있습니다.
#
# 차이점
# - ResNet-34의 경우 Block은 3x3 kernel인 Convolution layer로만 구성되어있지만, ResNet-50은 1x1 Convolution이 앞뒤로 붙어 더 많은 레이어를 한 블록 내에 가지게 됩니다.

# %% [markdown]
# -  ResNet의 블록을 직접 만들어 봅시다!
# - 모델 내의 앞과 뒤에서 반복되지 않을 것 같은 부분은 함수로 구현하지 않아도 됩니다.
# - 우리가 지금 만들어야 하는 것은 블록을 생성하는 함수
# - 이번 단계에서는 가급적 ResNet 논문을 통해서 구현방법에 대한 정보를 얻으시기를 권합니다.
# - 논문만 보고 스스로 구현해 보는 경험을 통해 딥러닝 개발자로서의 내공과 자신감이 다져지게 될 것

# %% [markdown]
# 2) ResNet-34, ResNet-50 Complete Model
# ResNet-34
#
# - VGG와 같이 블록을 만드는 함수를 사용해서 직접 전체 모델을 만들어 봅시다.
# - ResNet-34와 ResNet-50의 차이에 따라 달라지는 구성(configuration)을 함수에 전달해서 같은 생성 함수 build_resnet()를 통해서 ResNet의 여러가지 버전들을 모두 만들어 낼 수 있도록 해야 합니다.

# %%
from tensorflow import keras

# %% [markdown]
# ## ResNet 34 모델 만들기

# %%
def resnet34_blk1(output, cnt):
    output_2 = keras.layers.Activation('relu')(output)
    if cnt == 0:
        output_2 = keras.layers.MaxPooling2D(
            pool_size=(2,2),
            strides=2,
            name=f'stage{cnt+2}_maxpooling')(output_2)
        
        output = keras.layers.Conv2D(
            filters=64*(2**cnt),
            kernel_size=(3, 3),
            activation='relu',
            kernel_initializer='he_normal',
            padding='same',
            name = f'stage{cnt+2}_1_conv2_1')(output_2)
        
    else:
        output = keras.layers.Conv2D(
            filters=64*(2**cnt),
            kernel_size=(3, 3),
            strides = 2,
            activation='relu',
            kernel_initializer='he_normal',
            padding='same',
            name = f'stage{cnt+2}_1_conv2_1')(output_2) 
    
    output = keras.layers.BatchNormalization(name = f'stage{cnt+2}_1_bn1')(output)
    output = keras.layers.Activation('relu')(output)
    output = keras.layers.Conv2D(
        filters=64*(2**cnt),
        kernel_size=(3, 3),
        activation='relu',
        kernel_initializer='he_normal',
        padding='same',
        name = f'stage{cnt+2}_1_conv2_2')(output)
    output = keras.layers.BatchNormalization(name = f'stage{cnt+2}_1_bn2')(output)
    
    if cnt == 0:
        output_2 = keras.layers.Conv2D(
            filters=64*(2**cnt),
            kernel_size=(1, 1),
            activation='relu',
            kernel_initializer='he_normal',
            padding='valid',
            name = f'stage{cnt+2}_short')(output_2)
    else:
        output_2 = keras.layers.Conv2D(
        filters=64*(2**cnt),
        kernel_size=(1, 1),
        strides = 2,
        activation='relu',
        kernel_initializer='he_normal',
        padding='valid',
        name = f'stage{cnt+2}_short')(output_2)
    
    output = keras.layers.Activation('relu')(output)
    output_2 = keras.layers.BatchNormalization(name = f'stage{cnt+2}_1_bn3')(output_2)
    output = keras.layers.Add(name = f'stage{cnt+2}_1_add')([output, output_2])
    return output

# %%
def resnet34_blk2(output, cnt_blk1, cnt_blk2):
    output_2 = keras.layers.Activation('relu')(output)
    output = keras.layers.Conv2D(
        filters=64*(2**cnt_blk1),
        kernel_size=(3, 3),
        activation='relu',
        kernel_initializer='he_normal',
        padding='same',
        name = f'stage{cnt_blk1+2}_{cnt_blk2+2}_conv2_1')(output_2)
    output = keras.layers.BatchNormalization(name = f'stage{cnt_blk1+2}_{cnt_blk2+2}_bn_1')(output)
    output = keras.layers.Activation('relu')(output)
    output = keras.layers.Conv2D(
        filters=64*(2**cnt_blk1),
        kernel_size=(3, 3),
        activation='relu',
        kernel_initializer='he_normal',
        padding='same',
        name = f'stage{cnt_blk1+2}_{cnt_blk2+2}_conv2_2')(output)
    output = keras.layers.BatchNormalization(name = f'stage{cnt_blk1+2}_{cnt_blk2+2}_bn_2')(output)
    output = keras.layers.Activation('relu')(output)
    output = keras.layers.Add(name = f'stage{cnt_blk1+2}_{cnt_blk2+2}_add')([output, output_2])
    return output

# %%
# ResNet-34 생성 함수
def build_resnet34(input_shape=(32,32,3),num_classes=10):
    
    # 입력 레이어
    input_layer = keras.layers.Input(shape=input_shape, name='input_layer')
    output = input_layer
    output = keras.layers.Conv2D(
        filters=64,
        kernel_size=(7, 7),
        strides = 2,
        activation='relu',
        kernel_initializer='he_normal',
        padding='same')(output)
    output = keras.layers.BatchNormalization()(output)
    
    # blk1 수행 후, blk2 수행횟수
    blk2_cnt_list = [2, 3, 5, 2]
    
    # i : blk1 수행 횟수
    for i in range(4):
        output = resnet34_blk1(output, i)
        for j in range(blk2_cnt_list[i]):
            output = resnet34_blk2(output, i, j)

    # Activation
    output = keras.layers.Activation('relu')(output)

    # Average Pooling
    output = keras.layers.AveragePooling2D(pool_size=(1, 1), strides=1)(output)

    # Flatten width*height*channel을 1차원으로 변경
    output = keras.layers.Flatten(name='flatten_6')(output)
    
    output = keras.layers.Dense(num_classes, activation='softmax', name='fc1000')(output)
    # 왜인지 여기서 num_classes를 초기 값 넣어주면 에러남

    model = keras.Model(inputs = input_layer, outputs=output)

    return model

# %%
def build_resnet(input_shape=(32,32,3),num_classes=10, is_50=False):
    
    if is_50 == False:
        return build_resnet34(input_shape, num_classes)
    
    elif is_50 == True:
        return build_resnet50(input_shape, num_classes)

# %%
resnet_34 = build_resnet(input_shape=(32, 32,3), is_50=False)
resnet_34.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_layer (InputLayer)        [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 16, 16, 64)   9472        input_layer[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 16, 16, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 16, 16, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# stage2_maxpooling (MaxPooling2D (None, 8, 8, 64)     0           activation_49[0][0]
# __________________________________________________________________________________________________
# stage2_1_conv2_1 (Conv2D)       (None, 8, 8, 64)     36928       stage2_maxpooling[0][0]
# __________________________________________________________________________________________________
# stage2_1_bn1 (BatchNormalizatio (None, 8, 8, 64)     256         stage2_1_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 8, 8, 64)     0           stage2_1_bn1[0][0]
# __________________________________________________________________________________________________
# stage2_1_conv2_2 (Conv2D)       (None, 8, 8, 64)     36928       activation_50[0][0]
# __________________________________________________________________________________________________
# stage2_1_bn2 (BatchNormalizatio (None, 8, 8, 64)     256         stage2_1_conv2_2[0][0]
# __________________________________________________________________________________________________
# stage2_short (Conv2D)           (None, 8, 8, 64)     4160        stage2_maxpooling[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 8, 8, 64)     0           stage2_1_bn2[0][0]
# __________________________________________________________________________________________________
# stage2_1_bn3 (BatchNormalizatio (None, 8, 8, 64)     256         stage2_short[0][0]
# __________________________________________________________________________________________________
# stage2_1_add (Add)              (None, 8, 8, 64)     0           activation_51[0][0]
#                                                                  stage2_1_bn3[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 8, 8, 64)     0           stage2_1_add[0][0]
# __________________________________________________________________________________________________
# stage2_2_conv2_1 (Conv2D)       (None, 8, 8, 64)     36928       activation_52[0][0]
# __________________________________________________________________________________________________
# stage2_2_bn_1 (BatchNormalizati (None, 8, 8, 64)     256         stage2_2_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 8, 8, 64)     0           stage2_2_bn_1[0][0]
# __________________________________________________________________________________________________
# stage2_2_conv2_2 (Conv2D)       (None, 8, 8, 64)     36928       activation_53[0][0]
# __________________________________________________________________________________________________
# stage2_2_bn_2 (BatchNormalizati (None, 8, 8, 64)     256         stage2_2_conv2_2[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 8, 8, 64)     0           stage2_2_bn_2[0][0]
# __________________________________________________________________________________________________
# stage2_2_add (Add)              (None, 8, 8, 64)     0           activation_54[0][0]
#                                                                  activation_52[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 8, 8, 64)     0           stage2_2_add[0][0]
# __________________________________________________________________________________________________
# stage2_3_conv2_1 (Conv2D)       (None, 8, 8, 64)     36928       activation_55[0][0]
# __________________________________________________________________________________________________
# stage2_3_bn_1 (BatchNormalizati (None, 8, 8, 64)     256         stage2_3_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 8, 8, 64)     0           stage2_3_bn_1[0][0]
# __________________________________________________________________________________________________
# stage2_3_conv2_2 (Conv2D)       (None, 8, 8, 64)     36928       activation_56[0][0]
# __________________________________________________________________________________________________
# stage2_3_bn_2 (BatchNormalizati (None, 8, 8, 64)     256         stage2_3_conv2_2[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 8, 8, 64)     0           stage2_3_bn_2[0][0]
# __________________________________________________________________________________________________
# stage2_3_add (Add)              (None, 8, 8, 64)     0           activation_57[0][0]
#                                                                  activation_55[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 8, 8, 64)     0           stage2_3_add[0][0]
# __________________________________________________________________________________________________
# stage3_1_conv2_1 (Conv2D)       (None, 4, 4, 128)    73856       activation_58[0][0]
# __________________________________________________________________________________________________
# stage3_1_bn1 (BatchNormalizatio (None, 4, 4, 128)    512         stage3_1_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 4, 4, 128)    0           stage3_1_bn1[0][0]
# __________________________________________________________________________________________________
# stage3_1_conv2_2 (Conv2D)       (None, 4, 4, 128)    147584      activation_59[0][0]
# __________________________________________________________________________________________________
# stage3_1_bn2 (BatchNormalizatio (None, 4, 4, 128)    512         stage3_1_conv2_2[0][0]
# __________________________________________________________________________________________________
# stage3_short (Conv2D)           (None, 4, 4, 128)    8320        activation_58[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 4, 4, 128)    0           stage3_1_bn2[0][0]
# __________________________________________________________________________________________________
# stage3_1_bn3 (BatchNormalizatio (None, 4, 4, 128)    512         stage3_short[0][0]
# __________________________________________________________________________________________________
# stage3_1_add (Add)              (None, 4, 4, 128)    0           activation_60[0][0]
#                                                                  stage3_1_bn3[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 4, 4, 128)    0           stage3_1_add[0][0]
# __________________________________________________________________________________________________
# stage3_2_conv2_1 (Conv2D)       (None, 4, 4, 128)    147584      activation_61[0][0]
# __________________________________________________________________________________________________
# stage3_2_bn_1 (BatchNormalizati (None, 4, 4, 128)    512         stage3_2_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 4, 4, 128)    0           stage3_2_bn_1[0][0]
# __________________________________________________________________________________________________
# stage3_2_conv2_2 (Conv2D)       (None, 4, 4, 128)    147584      activation_62[0][0]
# __________________________________________________________________________________________________
# stage3_2_bn_2 (BatchNormalizati (None, 4, 4, 128)    512         stage3_2_conv2_2[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 4, 4, 128)    0           stage3_2_bn_2[0][0]
# __________________________________________________________________________________________________
# stage3_2_add (Add)              (None, 4, 4, 128)    0           activation_63[0][0]
#                                                                  activation_61[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 4, 4, 128)    0           stage3_2_add[0][0]
# __________________________________________________________________________________________________
# stage3_3_conv2_1 (Conv2D)       (None, 4, 4, 128)    147584      activation_64[0][0]
# __________________________________________________________________________________________________
# stage3_3_bn_1 (BatchNormalizati (None, 4, 4, 128)    512         stage3_3_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 4, 4, 128)    0           stage3_3_bn_1[0][0]
# __________________________________________________________________________________________________
# stage3_3_conv2_2 (Conv2D)       (None, 4, 4, 128)    147584      activation_65[0][0]
# __________________________________________________________________________________________________
# stage3_3_bn_2 (BatchNormalizati (None, 4, 4, 128)    512         stage3_3_conv2_2[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 4, 4, 128)    0           stage3_3_bn_2[0][0]
# __________________________________________________________________________________________________
# stage3_3_add (Add)              (None, 4, 4, 128)    0           activation_66[0][0]
#                                                                  activation_64[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 4, 4, 128)    0           stage3_3_add[0][0]
# __________________________________________________________________________________________________
# stage3_4_conv2_1 (Conv2D)       (None, 4, 4, 128)    147584      activation_67[0][0]
# __________________________________________________________________________________________________
# stage3_4_bn_1 (BatchNormalizati (None, 4, 4, 128)    512         stage3_4_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 4, 4, 128)    0           stage3_4_bn_1[0][0]
# __________________________________________________________________________________________________
# stage3_4_conv2_2 (Conv2D)       (None, 4, 4, 128)    147584      activation_68[0][0]
# __________________________________________________________________________________________________
# stage3_4_bn_2 (BatchNormalizati (None, 4, 4, 128)    512         stage3_4_conv2_2[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 4, 4, 128)    0           stage3_4_bn_2[0][0]
# __________________________________________________________________________________________________
# stage3_4_add (Add)              (None, 4, 4, 128)    0           activation_69[0][0]
#                                                                  activation_67[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 4, 4, 128)    0           stage3_4_add[0][0]
# __________________________________________________________________________________________________
# stage4_1_conv2_1 (Conv2D)       (None, 2, 2, 256)    295168      activation_70[0][0]
# __________________________________________________________________________________________________
# stage4_1_bn1 (BatchNormalizatio (None, 2, 2, 256)    1024        stage4_1_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 2, 2, 256)    0           stage4_1_bn1[0][0]
# __________________________________________________________________________________________________
# stage4_1_conv2_2 (Conv2D)       (None, 2, 2, 256)    590080      activation_71[0][0]
# __________________________________________________________________________________________________
# stage4_1_bn2 (BatchNormalizatio (None, 2, 2, 256)    1024        stage4_1_conv2_2[0][0]
# __________________________________________________________________________________________________
# stage4_short (Conv2D)           (None, 2, 2, 256)    33024       activation_70[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 2, 2, 256)    0           stage4_1_bn2[0][0]
# __________________________________________________________________________________________________
# stage4_1_bn3 (BatchNormalizatio (None, 2, 2, 256)    1024        stage4_short[0][0]
# __________________________________________________________________________________________________
# stage4_1_add (Add)              (None, 2, 2, 256)    0           activation_72[0][0]
#                                                                  stage4_1_bn3[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 2, 2, 256)    0           stage4_1_add[0][0]
# __________________________________________________________________________________________________
# stage4_2_conv2_1 (Conv2D)       (None, 2, 2, 256)    590080      activation_73[0][0]
# __________________________________________________________________________________________________
# stage4_2_bn_1 (BatchNormalizati (None, 2, 2, 256)    1024        stage4_2_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 2, 2, 256)    0           stage4_2_bn_1[0][0]
# __________________________________________________________________________________________________
# stage4_2_conv2_2 (Conv2D)       (None, 2, 2, 256)    590080      activation_74[0][0]
# __________________________________________________________________________________________________
# stage4_2_bn_2 (BatchNormalizati (None, 2, 2, 256)    1024        stage4_2_conv2_2[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 2, 2, 256)    0           stage4_2_bn_2[0][0]
# __________________________________________________________________________________________________
# stage4_2_add (Add)              (None, 2, 2, 256)    0           activation_75[0][0]
#                                                                  activation_73[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 2, 2, 256)    0           stage4_2_add[0][0]
# __________________________________________________________________________________________________
# stage4_3_conv2_1 (Conv2D)       (None, 2, 2, 256)    590080      activation_76[0][0]
# __________________________________________________________________________________________________
# stage4_3_bn_1 (BatchNormalizati (None, 2, 2, 256)    1024        stage4_3_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 2, 2, 256)    0           stage4_3_bn_1[0][0]
# __________________________________________________________________________________________________
# stage4_3_conv2_2 (Conv2D)       (None, 2, 2, 256)    590080      activation_77[0][0]
# __________________________________________________________________________________________________
# stage4_3_bn_2 (BatchNormalizati (None, 2, 2, 256)    1024        stage4_3_conv2_2[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 2, 2, 256)    0           stage4_3_bn_2[0][0]
# __________________________________________________________________________________________________
# stage4_3_add (Add)              (None, 2, 2, 256)    0           activation_78[0][0]
#                                                                  activation_76[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 2, 2, 256)    0           stage4_3_add[0][0]
# __________________________________________________________________________________________________
# stage4_4_conv2_1 (Conv2D)       (None, 2, 2, 256)    590080      activation_79[0][0]
# __________________________________________________________________________________________________
# stage4_4_bn_1 (BatchNormalizati (None, 2, 2, 256)    1024        stage4_4_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 2, 2, 256)    0           stage4_4_bn_1[0][0]
# __________________________________________________________________________________________________
# stage4_4_conv2_2 (Conv2D)       (None, 2, 2, 256)    590080      activation_80[0][0]
# __________________________________________________________________________________________________
# stage4_4_bn_2 (BatchNormalizati (None, 2, 2, 256)    1024        stage4_4_conv2_2[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 2, 2, 256)    0           stage4_4_bn_2[0][0]
# __________________________________________________________________________________________________
# stage4_4_add (Add)              (None, 2, 2, 256)    0           activation_81[0][0]
#                                                                  activation_79[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 2, 2, 256)    0           stage4_4_add[0][0]
# __________________________________________________________________________________________________
# stage4_5_conv2_1 (Conv2D)       (None, 2, 2, 256)    590080      activation_82[0][0]
# __________________________________________________________________________________________________
# stage4_5_bn_1 (BatchNormalizati (None, 2, 2, 256)    1024        stage4_5_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 2, 2, 256)    0           stage4_5_bn_1[0][0]
# __________________________________________________________________________________________________
# stage4_5_conv2_2 (Conv2D)       (None, 2, 2, 256)    590080      activation_83[0][0]
# __________________________________________________________________________________________________
# stage4_5_bn_2 (BatchNormalizati (None, 2, 2, 256)    1024        stage4_5_conv2_2[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 2, 2, 256)    0           stage4_5_bn_2[0][0]
# __________________________________________________________________________________________________
# stage4_5_add (Add)              (None, 2, 2, 256)    0           activation_84[0][0]
#                                                                  activation_82[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 2, 2, 256)    0           stage4_5_add[0][0]
# __________________________________________________________________________________________________
# stage4_6_conv2_1 (Conv2D)       (None, 2, 2, 256)    590080      activation_85[0][0]
# __________________________________________________________________________________________________
# stage4_6_bn_1 (BatchNormalizati (None, 2, 2, 256)    1024        stage4_6_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 2, 2, 256)    0           stage4_6_bn_1[0][0]
# __________________________________________________________________________________________________
# stage4_6_conv2_2 (Conv2D)       (None, 2, 2, 256)    590080      activation_86[0][0]
# __________________________________________________________________________________________________
# stage4_6_bn_2 (BatchNormalizati (None, 2, 2, 256)    1024        stage4_6_conv2_2[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 2, 2, 256)    0           stage4_6_bn_2[0][0]
# __________________________________________________________________________________________________
# stage4_6_add (Add)              (None, 2, 2, 256)    0           activation_87[0][0]
#                                                                  activation_85[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 2, 2, 256)    0           stage4_6_add[0][0]
# __________________________________________________________________________________________________
# stage5_1_conv2_1 (Conv2D)       (None, 1, 1, 512)    1180160     activation_88[0][0]
# __________________________________________________________________________________________________
# stage5_1_bn1 (BatchNormalizatio (None, 1, 1, 512)    2048        stage5_1_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 1, 1, 512)    0           stage5_1_bn1[0][0]
# __________________________________________________________________________________________________
# stage5_1_conv2_2 (Conv2D)       (None, 1, 1, 512)    2359808     activation_89[0][0]
# __________________________________________________________________________________________________
# stage5_1_bn2 (BatchNormalizatio (None, 1, 1, 512)    2048        stage5_1_conv2_2[0][0]
# __________________________________________________________________________________________________
# stage5_short (Conv2D)           (None, 1, 1, 512)    131584      activation_88[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 1, 1, 512)    0           stage5_1_bn2[0][0]
# __________________________________________________________________________________________________
# stage5_1_bn3 (BatchNormalizatio (None, 1, 1, 512)    2048        stage5_short[0][0]
# __________________________________________________________________________________________________
# stage5_1_add (Add)              (None, 1, 1, 512)    0           activation_90[0][0]
#                                                                  stage5_1_bn3[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 1, 1, 512)    0           stage5_1_add[0][0]
# __________________________________________________________________________________________________
# stage5_2_conv2_1 (Conv2D)       (None, 1, 1, 512)    2359808     activation_91[0][0]
# __________________________________________________________________________________________________
# stage5_2_bn_1 (BatchNormalizati (None, 1, 1, 512)    2048        stage5_2_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 1, 1, 512)    0           stage5_2_bn_1[0][0]
# __________________________________________________________________________________________________
# stage5_2_conv2_2 (Conv2D)       (None, 1, 1, 512)    2359808     activation_92[0][0]
# __________________________________________________________________________________________________
# stage5_2_bn_2 (BatchNormalizati (None, 1, 1, 512)    2048        stage5_2_conv2_2[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 1, 1, 512)    0           stage5_2_bn_2[0][0]
# __________________________________________________________________________________________________
# stage5_2_add (Add)              (None, 1, 1, 512)    0           activation_93[0][0]
#                                                                  activation_91[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 1, 1, 512)    0           stage5_2_add[0][0]
# __________________________________________________________________________________________________
# stage5_3_conv2_1 (Conv2D)       (None, 1, 1, 512)    2359808     activation_94[0][0]
# __________________________________________________________________________________________________
# stage5_3_bn_1 (BatchNormalizati (None, 1, 1, 512)    2048        stage5_3_conv2_1[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 1, 1, 512)    0           stage5_3_bn_1[0][0]
# __________________________________________________________________________________________________
# stage5_3_conv2_2 (Conv2D)       (None, 1, 1, 512)    2359808     activation_95[0][0]
# __________________________________________________________________________________________________
# stage5_3_bn_2 (BatchNormalizati (None, 1, 1, 512)    2048        stage5_3_conv2_2[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 1, 1, 512)    0           stage5_3_bn_2[0][0]
# __________________________________________________________________________________________________
# stage5_3_add (Add)              (None, 1, 1, 512)    0           activation_96[0][0]
#                                                                  activation_94[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 1, 1, 512)    0           stage5_3_add[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 512)    0           activation_97[0][0]
# __________________________________________________________________________________________________
# flatten_6 (Flatten)             (None, 512)          0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# fc1000 (Dense)                  (None, 10)           5130        flatten_6[0][0]
# ==================================================================================================
# Total params: 21,319,754
# Trainable params: 21,302,602
# Non-trainable params: 17,152
# __________________________________________________________________________________________________
